# %% [markdown]
# # Merging the datasets

# %%
import pandas as pd

# %% [markdown]
# ## Import CSV

# %%
boxoffice_tous= pd.read_csv('boxoffice_tous.csv')
boxoffice_top = pd.read_csv('boxoffice_top.csv')
boxoffice_topboxofficefr = pd.read_csv('boxoffice_topboxofficefr.csv')

merged_boxoffice = pd.concat([boxoffice_tous, boxoffice_top, boxoffice_topboxofficefr])

# %%
movies_tous = pd.read_csv('movies_tous.csv')
movies_top = pd.read_csv('movies_top.csv')
movies_topboxofficefr = pd.read_csv('movies_topboxofficefr.csv')

merged_movies = pd.concat([movies_tous, movies_top, movies_topboxofficefr])

# %% [markdown]
# ## Boxoffice dataset

# %%
merged_boxoffice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4797 entries, 0 to 50
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   titre        4797 non-null   object
#  1   semaine_1    4797 non-null   object
#  2   boxoffice_1  4797 non-null   object
#  3   boxoffice_2  4797 non-null   object
# dtypes: object(4)
# memory usage: 187.4+ KB

# %%
merged_boxoffice = merged_boxoffice.drop_duplicates()

# %%
merged_boxoffice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4642 entries, 0 to 113
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   titre        4642 non-null   object
#  1   semaine_1    4642 non-null   object
#  2   boxoffice_1  4642 non-null   object
#  3   boxoffice_2  4642 non-null   object
# dtypes: object(4)
# memory usage: 181.3+ KB

# %%
merged_boxoffice.head(5)
# Out:
#                    titre                         semaine_1 boxoffice_1  \
# 0             La La Land  \n25 janvier au 1 février 2017\n     754 534
# 1              Insidious            \n15 au 22 juin 2011\n     193 688
# 2                  Tenet   \n26 août au 2 septembre 2020\n     948 378
# 3          La Nuit du 12         \n13 au 20 juillet 2022\n      96 667
# 4  65 - la Terre d'avant            \n15 au 22 mars 2023\n     187 043
#
#   boxoffice_2
# 0     559 552
# 1     127 061
# 2     411 702
# 3      72 191
# 4      68 511

# %%
from datetime import datetime
import locale

def convert_to_dd_mm_aaaa(date_str):
    if date_str:
        try:
            # Set the locale manually for the script
            locale.setlocale(locale.LC_TIME, 'fr_FR.utf8')
            date_obj = datetime.strptime(date_str, '%d %B %Y')
            formatted_date = date_obj.strftime('%d/%m/%Y')
            return formatted_date
        except ValueError:
            return None
    return None

# %%
# Enlever les caractères "\n" de la colonne "semaine_1"
merged_boxoffice['semaine_1'] = merged_boxoffice['semaine_1'].str.strip('\n')

# Diviser la colonne "semaine_1" en deux colonnes "debut_semaine_1" et "fin_semaine_1"
merged_boxoffice[['debut_semaine_1', 'fin_semaine_1']] = merged_boxoffice['semaine_1'].str.split(' au ', expand=True)

# Convertir la colonne "fin_semaine_1" au format "dd/mm/aaaa"
merged_boxoffice['fin_semaine_1'] = merged_boxoffice['fin_semaine_1'].apply(convert_to_dd_mm_aaaa)

# Supprimer la colonne "debut_semaine_1" si nécessaire
merged_boxoffice.drop(columns=['debut_semaine_1'], inplace=True)

# %%
lignes_avec_valeurs_nulles = merged_boxoffice[merged_boxoffice.isnull().any(axis=1)]
lignes_avec_valeurs_nulles
# Out:
# Empty DataFrame
# Columns: [titre, semaine_1, boxoffice_1, boxoffice_2, fin_semaine_1]
# Index: []

# %%
merged_boxoffice = merged_boxoffice.dropna()

# %% [markdown]
# ## Movies dataset

# %%
merged_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9079 entries, 0 to 149
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   titre             9079 non-null   object
#  1   date              7017 non-null   object
#  2   genre             5957 non-null   object
#  3   durée             9036 non-null   float64
#  4   réalisateur       9067 non-null   object
#  5   distributeur      7660 non-null   object
#  6   acteurs           9047 non-null   object
#  7   titre_original    4035 non-null   object
#  8   nationalités      2299 non-null   object
#  9   langue_d_origine  9079 non-null   object
#  10  type_film         9079 non-null   object
#  11  annee_production  9079 non-null   int64
#  12  budget            9079 non-null   object
#  13  box_office_total  4641 non-null   object
#  14  note_presse       9063 non-null   object
#  15  note_spectateurs  5868 non-null   object
#  16  nombre_article    8949 non-null   object
#  17  recompenses       3787 non-null   object
#  18  description       8262 non-null   object
# dtypes: float64(1), int64(1), object(17)
# memory usage: 1.4+ MB

# %%
merged_movies = merged_movies.drop_duplicates()

# %%
merged_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8710 entries, 0 to 142
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   titre             8710 non-null   object
#  1   date              6668 non-null   object
#  2   genre             5703 non-null   object
#  3   durée             8667 non-null   float64
#  4   réalisateur       8698 non-null   object
#  5   distributeur      7304 non-null   object
#  6   acteurs           8678 non-null   object
#  7   titre_original    3841 non-null   object
#  8   nationalités      2200 non-null   object
#  9   langue_d_origine  8710 non-null   object
#  10  type_film         8710 non-null   object
#  11  annee_production  8710 non-null   int64
#  12  budget            8710 non-null   object
#  13  box_office_total  4489 non-null   object
#  14  note_presse       8694 non-null   object
#  15  note_spectateurs  5564 non-null   object
#  16  nombre_article    8586 non-null   object
#  17  recompenses       3492 non-null   object
#  18  description       7932 non-null   object
# dtypes: float64(1), int64(1), object(17)
# memory usage: 1.3+ MB

# %% [markdown]
# ## Merging the datasets boxoffice and movies

# %%
merged_dataset = pd.merge(merged_movies, merged_boxoffice, on='titre')

# %%
merged_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4679 entries, 0 to 4678
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   titre             4679 non-null   object
#  1   date              4423 non-null   object
#  2   genre             2983 non-null   object
#  3   durée             4673 non-null   float64
#  4   réalisateur       4679 non-null   object
#  5   distributeur      4575 non-null   object
#  6   acteurs           4659 non-null   object
#  7   titre_original    1871 non-null   object
#  8   nationalités      1301 non-null   object
#  9   langue_d_origine  4679 non-null   object
#  10  type_film         4679 non-null   object
#  11  annee_production  4679 non-null   int64
#  12  budget            4679 non-null   object
#  13  box_office_total  4342 non-null   object
#  14  note_presse       4676 non-null   object
#  15  note_spectateurs  4399 non-null   object
#  16  nombre_article    4666 non-null   object
#  17  recompenses       2263 non-null   object
#  18  description       4182 non-null   object
#  19  semaine_1         4679 non-null   object
#  20  boxoffice_1       4679 non-null   object
#  21  boxoffice_2       4679 non-null   object
#  22  fin_semaine_1     4679 non-null   object
# dtypes: float64(1), int64(1), object(21)
# memory usage: 877.3+ KB

# %%
merged_dataset.head()
# Out:
#                               titre        date     genre  durée  \
# 0  Une histoire d'amour et de désir  01/09/2021   Romance  102.0
# 1       Simone, le voyage du siècle  12/10/2022     Drame  140.0
# 2                   L'Odeur du vent  24/05/2023       NaN   90.0
# 3                   Coup de théâtre  14/09/2022  Policier   98.0
# 4                           Petites  22/02/2023       NaN   90.0
#
#            réalisateur                      distributeur  \
# 0         Leyla Bouzid            Pyramide Distribution
# 1        Olivier Dahan              Warner Bros. France
# 2       Hadi Mohaghegh                     Bodega Films
# 3           Tom George   The Walt Disney Company France
# 4  Julie Lerat-Gersant                    Haut et Court
#
#                                             acteurs    titre_original  \
# 0  Sami Outalbali,Zbeida Belhajamor,Diong-Keba Tacu               NaN
# 1    Elsa Zylberstein,Rebecca Marder,Élodie Bouchez               NaN
# 2                   Hadi Mohaghegh,Mohammad Eghbali              Derb
# 3           Sam Rockwell,Saoirse Ronan,Adrien Brody  See How They Run
# 4     Pili Groyne,Romane Bohringer,Victoire Du Bois               NaN
#
#   nationalités langue_d_origine  ...   box_office_total  note_presse  \
# 0          NaN  Français, Arabe  ...     38 765 entrées          4,0
# 1          NaN         Français  ...  2 470 567 entrées          3,1
# 2          NaN            Perse  ...     23 225 entrées          4,0
# 3          NaN          Anglais  ...    121 975 entrées          2,8
# 4          NaN         Français  ...     23 599 entrées          3,5
#
#   note_spectateurs         nombre_article              recompenses  \
# 0              3,8  25 articles de presse  1 prix et 9 nominations
# 1              4,1  29 articles de presse   2 prix et 1 nomination
# 2              3,6   6 articles de presse                      NaN
# 3              2,9  17 articles de presse                      NaN
# 4              3,8  20 articles de presse                      NaN
#
#                                          description  \
# 0  Ahmed, 18 ans, est français d’origine algérien...
# 1  Le destin de Simone Veil, son enfance, ses com...
# 2  Dans une maison isolée au milieu d’une plaine ...
# 3  Dans le West End des années 50 à Londres, la p...
# 4  Enceinte à 16 ans, Camille se retrouve placé...
#
#                    semaine_1 boxoffice_1 boxoffice_2 fin_semaine_1
# 0     01 au 8 septembre 2021      16 502       9 195    08/09/2021
# 1      12 au 19 octobre 2022     486 242     355 869    19/10/2022
# 2          24 au 31 mai 2023       8 528       4 978    31/05/2023
# 3    14 au 21 septembre 2022      56 893      34 963    21/09/2022
# 4  22 février au 1 mars 2023      12 466       4 783    01/03/2023
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Select the good boxoffice

# %%
# Comparer les colonnes "date" et "fin_semaine_1" pour déterminer quelle colonne "boxoffice" prendre
mask = merged_dataset['date'] == merged_dataset['fin_semaine_1']
merged_dataset['boxoffice'] = merged_dataset['boxoffice_2'].where(mask, merged_dataset['boxoffice_1'])

# Supprimer les colonnes inutiles
merged_dataset.drop(columns=['boxoffice_1', 'boxoffice_2', 'fin_semaine_1', 'semaine_1'], inplace=True)

# Afficher le dataframe final
print(merged_dataset)
# Out:
#                                         titre        date  \
# 0            Une histoire d'amour et de désir  01/09/2021
# 1                 Simone, le voyage du siècle  12/10/2022
# 2                             L'Odeur du vent  24/05/2023
# 3                             Coup de théâtre  14/09/2022
# 4                                     Petites  22/02/2023
# ...                                       ...         ...
# 4674                                Dragons 2  02/07/2014
# 4675        Harry Potter et l'Ordre du Phénix  11/07/2007
# 4676                             Spider-Man 3  01/05/2007
# 4677  Harry Potter et le Prisonnier d'Azkaban  02/06/2004
# 4678                         Le Monde de Nemo  26/11/2003
#
#                        genre  durée          réalisateur  \
# 0                    Romance  102.0         Leyla Bouzid
# 1                      Drame  140.0        Olivier Dahan
# 2                        NaN   90.0       Hadi Mohaghegh
# 3                   Policier   98.0           Tom George
# 4                        NaN   90.0  Julie Lerat-Gersant
# ...                      ...    ...                  ...
# 4674        Aventure,Famille  103.0         Dean DeBlois
# 4675  Aventure,Drame,Famille  138.0          David Yates
# 4676                  Action  139.0            Sam Raimi
# 4677                Aventure  140.0       Alfonso Cuarón
# 4678        Aventure,Famille  101.0       Andrew Stanton
#
#                           distributeur  \
# 0               Pyramide Distribution
# 1                 Warner Bros. France
# 2                        Bodega Films
# 3      The Walt Disney Company France
# 4                       Haut et Court
# ...                                ...
# 4674     Twentieth Century Fox France
# 4675              Warner Bros. France
# 4676   Gaumont Columbia Tristar Films
# 4677              Warner Bros. France
# 4678   The Walt Disney Company France
#
#                                                acteurs  \
# 0     Sami Outalbali,Zbeida Belhajamor,Diong-Keba Tacu
# 1       Elsa Zylberstein,Rebecca Marder,Élodie Bouchez
# 2                      Hadi Mohaghegh,Mohammad Eghbali
# 3              Sam Rockwell,Saoirse Ronan,Adrien Brody
# 4        Pili Groyne,Romane Bohringer,Victoire Du Bois
# ...                                                ...
# 4674       Donald Reignoux,Jay Baruchel,Cate Blanchett
# 4675         Daniel Radcliffe,Rupert Grint,Emma Watson
# 4676          Tobey Maguire,Kirsten Dunst,James Franco
# 4677         Daniel Radcliffe,Rupert Grint,Emma Watson
# 4678       Franck Dubosc,Albert Brooks,Ellen DeGeneres
#
#                                  titre_original            nationalités  \
# 0                                           NaN                     NaN
# 1                                           NaN                     NaN
# 2                                          Derb                     NaN
# 3                              See How They Run                     NaN
# 4                                           NaN                     NaN
# ...                                         ...                     ...
# 4674                 How to Train Your Dragon 2                     NaN
# 4675  Harry Potter and the Order of the Phoenix  U.S.A.,Grande-Bretagne
# 4676                                        NaN                     NaN
# 4677   Harry Potter and the Prisoner of Azkaban  U.S.A.,Grande-Bretagne
# 4678                               Finding Nemo                     NaN
#
#      langue_d_origine     type_film  annee_production         budget  \
# 0     Français, Arabe  Long-métrage              2021         2,6 M€
# 1            Français  Long-métrage              2022              -
# 2               Perse  Long-métrage              2022              -
# 3             Anglais  Long-métrage              2022              -
# 4            Français  Long-métrage              2022              -
# ...               ...           ...               ...            ...
# 4674          Anglais  Long-métrage              2014  145 000 000 $
# 4675          Anglais  Long-métrage              2007  150 000 000 $
# 4676          Anglais  Long-métrage              2007  258 000 000 $
# 4677          Anglais  Long-métrage              2004  130 000 000 $
# 4678          Anglais  Long-métrage              2003   94 000 000 $
#
#        box_office_total note_presse note_spectateurs  \
# 0        38 765 entrées         4,0              3,8
# 1     2 470 567 entrées         3,1              4,1
# 2        23 225 entrées         4,0              3,6
# 3       121 975 entrées         2,8              2,9
# 4        23 599 entrées         3,5              3,8
# ...                 ...         ...              ...
# 4674  3 294 432 entrées         4,0              4,2
# 4675  6 142 012 entrées         3,1              3,8
# 4676  6 329 254 entrées         3,7              3,5
# 4677  6 859 118 entrées         3,8              4,0
# 4678  9 077 546 entrées         4,5              4,2
#
#                  nombre_article               recompenses  \
# 0         25 articles de presse   1 prix et 9 nominations
# 1         29 articles de presse    2 prix et 1 nomination
# 2          6 articles de presse                       NaN
# 3         17 articles de presse                       NaN
# 4         20 articles de presse                       NaN
# ...                         ...                       ...
# 4674  985 Critiques Spectateurs   1 prix et 4 nominations
# 4675      18 articles de presse  2 prix et 14 nominations
# 4676      27 articles de presse  1 prix et 13 nominations
# 4677      14 articles de presse   1 prix et 7 nominations
# 4678  845 Critiques Spectateurs   1 prix et 8 nominations
#
#                                             description  boxoffice
# 0     Ahmed, 18 ans, est français d’origine algérien...     16 502
# 1     Le destin de Simone Veil, son enfance, ses com...    486 242
# 2     Dans une maison isolée au milieu d’une plaine ...      8 528
# 3     Dans le West End des années 50 à Londres, la p...     56 893
# 4     Enceinte à 16 ans, Camille se retrouve placé...     12 466
# ...                                                 ...        ...
# 4674                                                NaN  1 340 940
# 4675  Alors qu'il entame sa cinquième année d'études...  2 486 291
# 4676  Peter Parker a enfin réussi à concilier son am...  2 778 533
# 4677  Sirius Black, un dangereux sorcier criminel, s...  2 503 699
# 4678  Dans les eaux tropicales de la Grande Barrière...  2 056 621
#
# [4679 rows x 20 columns]

# %%
merged_dataset.to_csv('../../machine_learning/data/dataset_bronze.csv', index=False)
