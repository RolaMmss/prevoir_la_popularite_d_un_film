# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# %%
# import dataset
df = pd.read_csv('../feature engineering/data/dataset_gold.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10195 entries, 0 to 10194
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   titre                  10195 non-null  object
#  1   date                   3950 non-null   object
#  2   genre                  10195 non-null  object
#  3   durée                  10195 non-null  float64
#  4   réalisateur            10195 non-null  object
#  5   distributeur           10195 non-null  object
#  6   acteurs                10195 non-null  object
#  7   nationalités           10195 non-null  object
#  8   langue_d_origine       10134 non-null  object
#  9   type_film              10195 non-null  object
#  10  annee_production       10195 non-null  int64
#  11  box_office_total       8347 non-null   float64
#  12  note_presse            10195 non-null  float64
#  13  note_spectateurs       10195 non-null  float64
#  14  nombre_article         9781 non-null   float64
#  15  description            9185 non-null   object
#  16  boxoffice              10195 non-null  int64
#  17  awards                 10195 non-null  int64
#  18  nominations            10195 non-null  int64
#  19  nombre_acteurs_connus  10195 non-null  int64
#  20  acteurs_connus         10195 non-null  object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 1.6+ MB

# %%
df.columns
# Out:
# Index(['titre', 'date', 'genre', 'durée', 'réalisateur', 'distributeur',
#        'acteurs', 'nationalités', 'langue_d_origine', 'type_film',
#        'annee_production', 'box_office_total', 'note_presse',
#        'note_spectateurs', 'nombre_article', 'description', 'boxoffice',
#        'awards', 'nominations', 'nombre_acteurs_connus', 'acteurs_connus'],
#       dtype='object')

# %%
df.tail(10)
# Out:
#                                titre date                             genre  \
# 10185              I Heard the Bells  NaN          Drame/Romance,Historique
# 10186                      Crossover  NaN     Action/Aventure,Drame/Romance
# 10187                   Papas chéris  NaN                           Comédie
# 10188      Nothing Like the Holidays  NaN                Comédie dramatique
# 10189              A Madea Christmas  NaN                           Comédie
# 10190         La Mujer de mi hermano  NaN                     Drame/Romance
# 10191                         Gracie  NaN                     Drame/Romance
# 10192     Keeping up with the Steins  NaN                           Comédie
# 10193  Impractical Jokers: The Movie  NaN                           Comédie
# 10194                Meet the Browns  NaN  Comédie dramatique,Drame/Romance
#
#             durée             réalisateur distributeur  \
# 10185  103.340349             Joshua Enck      inconnu
# 10186  103.340349  Preston A. Whitmore II      inconnu
# 10187   86.000000            Cheryl Dunye      inconnu
# 10188   99.000000        Alfredo De Villa      inconnu
# 10189  105.000000             Tyler Perry      inconnu
# 10190   89.000000    Ricardo de Montreuil      inconnu
# 10191   97.000000        Davis Guggenheim      inconnu
# 10192   99.000000          Scott Marshall      inconnu
# 10193   93.000000            Chris Henchy      inconnu
# 10194  103.340349             Tyler Perry      inconnu
#
#                                                  acteurs nationalités  \
# 10185  ['Stephen Atherholt', 'Jonathan Blair', 'Rache...       U.S.A.
# 10186  ['Anthony Mackie', 'Wesley Jonathan', 'Wayne B...       U.S.A.
# 10187  ['Eddie Griffin', 'Anthony Anderson', 'Michael...       U.S.A.
# 10188  ['Jay Hernandez', 'Melonie Diaz', 'Alfred Moli...       U.S.A.
# 10189  ['Tyler Perry', 'Anna Maria Horsford', ' Larry...       U.S.A.
# 10190  ['Bárbara Mori', 'Christian Meier', 'Manolo Ca...    Argentine
# 10191  ['Carly Schroeder', 'Dermot Mulroney', 'Jesse ...       U.S.A.
# 10192   ['Jami Gertz', 'Daryl Hannah', 'Garry Marshall']       U.S.A.
# 10193        ['Brian Quinn', 'Joe Gatto', 'Sal Vulcano']       U.S.A.
# 10194  ['Angela Bassett', 'Tyler Perry', 'Jenifer Lew...       U.S.A.
#
#       langue_d_origine     type_film  ...  box_office_total  note_presse  \
# 10185          Anglais  Long-métrage  ...               NaN      3.06052
# 10186          Anglais  Long-métrage  ...               NaN      2.40000
# 10187          Anglais  Long-métrage  ...               NaN      2.80000
# 10188          Anglais  Long-métrage  ...               NaN      2.60000
# 10189          Anglais  Long-métrage  ...               NaN      2.90000
# 10190         Espagnol  Long-métrage  ...               NaN      3.00000
# 10191          Anglais  Long-métrage  ...               NaN      2.80000
# 10192          Anglais  Long-métrage  ...               NaN      2.60000
# 10193          Anglais  Long-métrage  ...               NaN      3.10000
# 10194          Anglais  Long-métrage  ...               NaN      2.50000
#
#        note_spectateurs  nombre_article  \
# 10185          3.016116             NaN
# 10186          3.016116             1.0
# 10187          3.016116             1.0
# 10188          3.016116             2.0
# 10189          3.016116             NaN
# 10190          3.016116             NaN
# 10191          3.016116             NaN
# 10192          3.016116             1.0
# 10193          3.016116             NaN
# 10194          3.016116             1.0
#
#                                              description boxoffice  awards  \
# 10185  Connu comme le poète de l'Amérique, Henry Wads...   2001603       0
# 10186  Un basketteur naturellement doué, Noah Cruise ...   3767567       0
# 10187  Trois jeunes hommes sont forcés d'entrer dans ...   7548819       0
# 10188  Une réunion de famille mouvementée, pendant le...   3531664       0
# 10189                                                NaN  16007634       1
# 10190  La monotonie gagne le couple de Zoe, jeune fem...   1018750       0
# 10191  En 1978, une adolescente dont le frère, as du ...   1355904       0
# 10192  Benjamin, un jeune garçon juif de 13 ans est s...    653723       0
# 10193  Quatre amis, Joe, Q, Murr et Sal, alias les Jo...   3545000       0
# 10194  Brenda est une mère célibataire qui vit à Chic...  20082809       0
#
#        nominations  nombre_acteurs_connus  acteurs_connus
# 10185            0                      0              []
# 10186            0                      0              []
# 10187            0                      0              []
# 10188            0                      0              []
# 10189            5                      0              []
# 10190            0                      0              []
# 10191            0                      0              []
# 10192            0                      0              []
# 10193            0                      0              []
# 10194            0                      0              []
#
# [10 rows x 21 columns]

# %%
# Utiliser la fonction "get_dummies" de pandas pour effectuer l'encodage
genres_encoded = df['genre'].str.join('|').str.get_dummies()

# Fusionner les colonnes encodées avec le DataFrame original
df_encoded = pd.concat([df, genres_encoded], axis=1).drop('genre', axis=1)

print(df_encoded)
# Out:
#                                     titre        date       durée  \
# 0               Super Mario Bros, le film  2023-05-04   92.000000
# 1      Les Vengeances de Maître Poutifard         NaN   90.000000
# 2                         Des mains en or  2023-07-06   90.000000
# 3                            The Covenant         NaN  123.000000
# 4                     Cléo, Melvil et moi  2023-05-07   73.000000
# ...                                   ...         ...         ...
# 10190              La Mujer de mi hermano         NaN   89.000000
# 10191                              Gracie         NaN   97.000000
# 10192          Keeping up with the Steins         NaN   99.000000
# 10193       Impractical Jokers: The Movie         NaN   93.000000
# 10194                     Meet the Browns         NaN  103.340349
#
#                         réalisateur                             distributeur  \
# 0                     Aaron Horvath  Universal Pictures International France
# 1      Pierre-François Martin-Laval                         UGC Distribution
# 2                 Isabelle Mergault                                Zinc Film
# 3                       Guy Ritchie                                  inconnu
# 4                      Arnaud Viard             Moonlight Films Distribution
# ...                             ...                                      ...
# 10190          Ricardo de Montreuil                                  inconnu
# 10191              Davis Guggenheim                                  inconnu
# 10192                Scott Marshall                                  inconnu
# 10193                  Chris Henchy                                  inconnu
# 10194                   Tyler Perry                                  inconnu
#
#                                                  acteurs     nationalités  \
# 0      ['Pierre Tessier', 'Chris Pratt', 'Jérémie Cov...           U.S.A.
# 1      ['Christian Clavier', 'Isabelle Nanty', 'Jenni...           France
# 2      ['Lambert Wilson', 'Josiane Balasko', 'Sylvie ...           France
# 3      ['Jake Gyllenhaal', 'Dar Salim', 'Alexander Lu...  Grande-Bretagne
# 4      ['Arnaud Viard', 'Marianne Denicourt', 'Romane...           France
# ...                                                  ...              ...
# 10190  ['Bárbara Mori', 'Christian Meier', 'Manolo Ca...        Argentine
# 10191  ['Carly Schroeder', 'Dermot Mulroney', 'Jesse ...           U.S.A.
# 10192   ['Jami Gertz', 'Daryl Hannah', 'Garry Marshall']           U.S.A.
# 10193        ['Brian Quinn', 'Joe Gatto', 'Sal Vulcano']           U.S.A.
# 10194  ['Angela Bassett', 'Tyler Perry', 'Jenifer Lew...           U.S.A.
#
#       langue_d_origine     type_film  annee_production  ...  n  o  p  q  r  s  \
# 0              Anglais  Long-métrage              2023  ...  1  1  0  0  0  0
# 1             Français  Long-métrage              2023  ...  0  1  0  0  0  0
# 2             Français  Long-métrage              2023  ...  0  1  0  0  0  0
# 3              Anglais  Long-métrage              2023  ...  1  1  0  0  1  0
# 4             Français  Long-métrage              2023  ...  0  1  0  1  1  0
# ...                ...           ...               ...  ... .. .. .. .. .. ..
# 10190         Espagnol  Long-métrage              2005  ...  1  1  0  0  1  0
# 10191          Anglais  Long-métrage              2007  ...  1  1  0  0  1  0
# 10192          Anglais  Long-métrage              2006  ...  0  1  0  0  0  0
# 10193          Anglais  Long-métrage              2020  ...  0  1  0  0  0  0
# 10194          Anglais  Long-métrage              2008  ...  1  1  0  1  1  0
#
#        t  u  v  é
# 0      1  0  0  1
# 1      0  0  0  1
# 2      0  0  0  1
# 3      1  1  1  0
# 4      1  1  0  1
# ...   .. .. .. ..
# 10190  0  0  0  0
# 10191  0  0  0  0
# 10192  0  0  0  1
# 10193  0  0  0  1
# 10194  1  1  0  1
#
# [10195 rows x 54 columns]

# %%
# from sklearn.model_selection import train_test_split
# X = df.drop(['boxoffice','date','acteurs','awards','box_office_total',
#        'description','nominations','note_presse','note_spectateurs', 'nombre_article','acteurs_connus'], axis=1)
# y = df['boxoffice']
# X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, shuffle=True, random_state=42)

# %%
# from sklearn.model_selection import train_test_split
# X = df.drop(['boxoffice','date','acteurs','awards','box_office_total',
#        'description','nominations','note_presse','note_spectateurs', 'nombre_article','acteurs_connus','titre','réalisateur','distributeur','langue_d_origine','genres'], axis=1)
# y = df['boxoffice']
# X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, shuffle=True, random_state=42)

# %%
# X

# %%
# X.isnull().sum()

# %%
# X.info()

# %%
# X.describe()

# %%
# # Import des bibliothèques
# from sklearn.pipeline import Pipeline
# from sklearn.preprocessing import OneHotEncoder, StandardScaler
# from sklearn.compose import ColumnTransformer
# from sklearn.linear_model import LinearRegression

# # Définir vos caractéristiques catégorielles et numériques
# # categorical_features = ['titre','réalisateur','distributeur','nationalités','langue_d_origine','type_film','genres']
# categorical_features = ['nationalités','type_film']

# numerical_features = ['durée', 'annee_production','nombre_acteurs_connus']

# # Créer le transformateur pour les caractéristiques catégorielles
# categorical_transformer = OneHotEncoder(sparse=True)

# # Créer le transformateur pour les caractéristiques numériques
# numerical_transformer = StandardScaler()

# # Créer le preprocessor en utilisant le ColumnTransformer pour gérer les deux types de caractéristiques
# preprocessor = ColumnTransformer(
#     transformers=[
#         ('cat', categorical_transformer, categorical_features),
#         ('num', numerical_transformer, numerical_features)
#     ],
#     remainder="passthrough" 
# )

# # Créer le modèle de régression linéaire
# lin_reg = LinearRegression()

# # Créer le pipeline en spécifiant les étapes dans l'ordre
# pipe = Pipeline([
#      ('preprocessor', preprocessor),
#      ('lin_reg', lin_reg)
# ])

# pipe

# %%
df.columns
# Out:
# Index(['titre', 'date', 'genre', 'durée', 'réalisateur', 'distributeur',
#        'acteurs', 'nationalités', 'langue_d_origine', 'type_film',
#        'annee_production', 'box_office_total', 'note_presse',
#        'note_spectateurs', 'nombre_article', 'description', 'boxoffice',
#        'awards', 'nominations', 'nombre_acteurs_connus', 'acteurs_connus'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
# X = df.drop(['boxoffice','date','acteurs','awards','box_office_total',
#        'description','nominations','note_presse','note_spectateurs', 'nombre_article','acteurs_connus','nationalités','langue_d_origine','genres','titre'], axis=1)

# Les colonnes à guarger:'titre','durée', 'réalisateur', 'distributeur','nationalités', 'langue_d_origine', 'type_film', 'annee_production','nombre_article','description', 
# 'genres','nombre_acteurs_connus',

X = df.drop(['boxoffice','date','acteurs','awards','box_office_total',
        'description','nominations','note_presse','note_spectateurs', 'nombre_article','acteurs_connus','titre','genre'], axis=1)
y = df['boxoffice']
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, shuffle=True, random_state=42)

# %%
X.head(5)
# Out:
#    durée                   réalisateur  \
# 0   92.0                 Aaron Horvath
# 1   90.0  Pierre-François Martin-Laval
# 2   90.0             Isabelle Mergault
# 3  123.0                   Guy Ritchie
# 4   73.0                  Arnaud Viard
#
#                               distributeur     nationalités langue_d_origine  \
# 0  Universal Pictures International France           U.S.A.          Anglais
# 1                         UGC Distribution           France         Français
# 2                                Zinc Film           France         Français
# 3                                  inconnu  Grande-Bretagne          Anglais
# 4             Moonlight Films Distribution           France         Français
#
#       type_film  annee_production  nombre_acteurs_connus
# 0  Long-métrage              2023                      1
# 1  Long-métrage              2023                      1
# 2  Long-métrage              2023                      2
# 3  Long-métrage              2023                      1
# 4  Long-métrage              2023                      0

# %%
# Import des bibliothèques
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression

# Définir vos caractéristiques catégorielles et numériques
# categorical_features = ['titre','réalisateur','distributeur','nationalités','langue_d_origine','type_film','genres']
categorical_features = ['réalisateur','distributeur','nationalités','langue_d_origine','type_film']

numerical_features = ['durée', 'annee_production','nombre_acteurs_connus']

# Créer le transformateur pour les caractéristiques catégorielles
categorical_transformer = OneHotEncoder(sparse=True)

# Créer le transformateur pour les caractéristiques numériques
numerical_transformer = StandardScaler()

# Créer le preprocessor en utilisant le ColumnTransformer pour gérer les deux types de caractéristiques
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', categorical_transformer, categorical_features),
        ('num', numerical_transformer, numerical_features)
    ],
    remainder="passthrough" 
)

# Créer le modèle de régression linéaire
lin_reg = LinearRegression()

# Créer le pipeline en spécifiant les étapes dans l'ordre
pipe = Pipeline([
     ('preprocessor', preprocessor),
     ('lin_reg', lin_reg)
])

pipe
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(sparse=True),
#                                                   ['réalisateur',
#                                                    'distributeur',
#                                                    'nationalités',
#                                                    'langue_d_origine',
#                                                    'type_film']),
#                                                  ('num', StandardScaler(),
#                                                   ['durée', 'annee_production',
#                                                    'nombre_acteurs_connus'])])),
#                 ('lin_reg', LinearRegression())])

# %%
# Ajuster (fit) le pipeline avec les données d'entraînement
pipe.fit(X_train, y_train)
# Out:
# /home/apprenant/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(sparse=True),
#                                                   ['réalisateur',
#                                                    'distributeur',
#                                                    'nationalités',
#                                                    'langue_d_origine',
#                                                    'type_film']),
#                                                  ('num', StandardScaler(),
#                                                   ['durée', 'annee_production',
#                                                    'nombre_acteurs_connus'])])),
#                 ('lin_reg', LinearRegression())])

# %%
# Maintenant que le pipeline est ajusté, vous pouvez faire des prédictions
y_pred_train = pipe.predict(X_train)
y_pred_test = pipe.predict(X_test)
y_pred_test
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 3
#       1 # Maintenant que le pipeline est ajusté, vous pouvez faire des prédictions
#       2 y_pred_train = pipe.predict(X_train)
# ----> 3 y_pred_test = pipe.predict(X_test)
#       4 y_pred_test
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/pipeline.py:507, in Pipeline.predict(self, X, **predict_params)
#     505 Xt = X
#     506 for _, name, transform in self._iter(with_final=False):
# --> 507     Xt = transform.transform(Xt)
#     508 return self.steps[-1][1].predict(Xt, **predict_params)
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/utils/_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return_tuple = (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/compose/_column_transformer.py:816, in ColumnTransformer.transform(self, X)
#     811 else:
#     812     # ndarray was used for fitting or transforming, thus we only
#     813     # check that n_features_in_ is consistent
#     814     self._check_n_features(X, reset=False)
# --> 816 Xs = self._fit_transform(
#     817     X,
#     818     None,
#     819     _transform_one,
#     820     fitted=True,
#     821     column_as_strings=fit_dataframe_and_transform_dataframe,
#     822 )
#     823 self._validate_output(Xs)
#     825 if not Xs:
#     826     # All transformers are None
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/compose/_column_transformer.py:670, in ColumnTransformer._fit_transform(self, X, y, func, fitted, column_as_strings)
#     664 transformers = list(
#     665     self._iter(
#     666         fitted=fitted, replace_strings=True, column_as_strings=column_as_strings
#     667     )
#     668 )
#     669 try:
# --> 670     return Parallel(n_jobs=self.n_jobs)(
#     671         delayed(func)(
#     672             transformer=clone(trans) if not fitted else trans,
#     673             X=_safe_indexing(X, column, axis=1),
#     674             y=y,
#     675             weight=weight,
#     676             message_clsname="ColumnTransformer",
#     677             message=self._log_message(name, idx, len(transformers)),
#     678         )
#     679         for idx, (name, trans, column, weight) in enumerate(transformers, 1)
#     680     )
#     681 except ValueError as e:
#     682     if "Expected 2D array, got 1D array instead" in str(e):
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/utils/parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/joblib/parallel.py:1855, in Parallel.__call__(self, iterable)
#    1853     output = self._get_sequential_output(iterable)
#    1854     next(output)
# -> 1855     return output if self.return_generator else list(output)
#    1857 # Let's create an ID that uniquely identifies the current call. If the
#    1858 # call is interrupted early and that the same instance is immediately
#    1859 # re-used, this id will be used to prevent workers that were
#    1860 # concurrently finalizing a task from the previous call to run the
#    1861 # callback.
#    1862 with self._lock:
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/joblib/parallel.py:1784, in Parallel._get_sequential_output(self, iterable)
#    1782 self.n_dispatched_batches += 1
#    1783 self.n_dispatched_tasks += 1
# -> 1784 res = func(*args, **kwargs)
#    1785 self.n_completed_tasks += 1
#    1786 self.print_progress()
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/utils/parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/pipeline.py:933, in _transform_one(transformer, X, y, weight, **fit_params)
#     932 def _transform_one(transformer, X, y, weight, **fit_params):
# --> 933     res = transformer.transform(X)
#     934     # if we have a weight for this transformer, multiply output
#     935     if weight is None:
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/utils/_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return_tuple = (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:1016, in OneHotEncoder.transform(self, X)
#    1011 # validation of X happens in _check_X called by _transform
#    1012 warn_on_unknown = self.drop is not None and self.handle_unknown in {
#    1013     "ignore",
#    1014     "infrequent_if_exist",
#    1015 }
# -> 1016 X_int, X_mask = self._transform(
#    1017     X,
#    1018     handle_unknown=self.handle_unknown,
#    1019     force_all_finite="allow-nan",
#    1020     warn_on_unknown=warn_on_unknown,
#    1021 )
#    1023 n_samples, n_features = X_int.shape
#    1025 if self._drop_idx_after_grouping is not None:
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:199, in _BaseEncoder._transform(self, X, handle_unknown, force_all_finite, warn_on_unknown, ignore_category_indices)
#     194 if handle_unknown == "error":
#     195     msg = (
#     196         "Found unknown categories {0} in column {1}"
#     197         " during transform".format(diff, i)
#     198     )
# --> 199     raise ValueError(msg)
#     200 else:
#     201     if warn_on_unknown:
#
# ValueError: Found unknown categories ['Natalie Morales', 'Sung-ho Park', 'Antoine Raimbault', 'Mauro Bolognini', 'Tom George', 'Christian De Vita', 'Cory Finley', 'Javier Rebollo', 'Sergio Corbucci', 'John Maybury', 'Peter Bebjak', 'Danielle Arbid', 'Shane Carruth', 'Sam Peckinpah', 'Anders Øvergaard', 'Akan Satayev', 'György Kristóf', 'Yves Thomas', 'Özcan Alper', 'Karyn Kusama', 'Dante Ariola', 'Manuel Martín Cuenca', 'Carlos Chahine', 'Rob Pritts', 'Richard Driscoll', 'Marí Alessandrini', 'Judith Davis', 'Maria Sødahl', 'Myriam Verreault', 'Brian Dannelly', 'David Elliot', 'Ida Lupino', 'Paolo Taviani', 'Fabrice Benchaouche', 'Adrian Biniez', 'Courtney Solomon', 'Marco Danieli', 'J.D. Dillard', 'Jean-Pierre Miquel', 'Paul Manate', 'Tayfun Pirselimoglu', 'Dylan Brown (II)', 'Charles Belmont', 'Zsófia Szilágyi', 'Joe Begos', 'Edoardo Winspeare', 'Edward Norton', 'Adrian Lyne', 'Russell Mulcahy', 'Daniel Roby', 'Futoshi Sato', 'Jean Dréville', 'Greg Marcks', 'Jean-Claude Lord', 'Zsolt Pálfi', 'Koen Mortier', 'Russell Crowe', 'Rocco Papaleo', 'Reinaldo Marcus Green', 'Vera Cais', 'Emilie Carpentier', 'A. B. Shawky', 'Jean-Christophe Roger (II)', 'Dominique Cabrera', "Vanja D'Alcantara", 'Jérôme Dassier', 'Daniel Duqué', 'Dan Bradley', 'Pamela Varela', 'Catherine Diran', 'Dan St. Pierre', 'Nicolas Brossette', 'Peter Sollett', 'C.B. Harding', 'Frank Marshall', 'Bruno Deville', 'Josh Baker', 'Agnieszka Wojtowicz-Vosloo', 'Fabián Hernández', 'Rob Grant', 'Derrick Borte', 'Georges Guillot', 'Lisa Bierwirth', 'Josée Dayan', 'Stijn Coninx', 'Gérard Bitton', 'Clay Kaytis', 'Steven Antin', 'Matt Eskandari', 'Aaron Horvath', 'Rebecca Miller', 'Alexandre De La Patellière', 'Simon Hunter', 'Andreas Horvath', 'Rob Hardy', 'Nia DaCosta', 'Damien Ounouri', 'Simone Godano', 'Steve Trenbirth', 'Pa Ranjith', 'Chad Chenouga', 'Jacques-Hervé Fichet', 'Kyle Marvin', 'Delmer Daves', 'Masahiro Andô', 'François Descraques', 'Max Mayer', 'Ronan De Suin', 'Juanjo Giménez Peña', 'Alejandro Loayza Grisi', 'Robert Enrico', 'Karey Kirkpatrick', 'Iram Haq', 'Eñaut Castagnet', 'Alain Monne', "Benoît d'Aubert", 'Stephan Lacant', 'Joseph Morder', 'Delbert Mann', 'Cody Cameron', 'Arturo Ripstein', 'Judy Morris', 'Amro Hamzawi', 'Adam Smith (II)', 'Véronique Reymond', 'Mariana Rondón', 'Ventura Pons', 'Claire Devers', 'Ferit Karahan', 'Serge Elissalde', 'Djinn Carrenard', 'Leon Prudovsky', 'Sean McCormack (II)', 'Ron Krauss', 'Marcos Jorge', 'Liam Lynch', 'Júlio Bressane', 'Alexandra-Therese Keining', 'Yerlan Nurmukhambetov', 'Shyam Madiraju', 'David Kerr', 'Stéphane Giusti', 'Lili Fini Zanuck', 'Kabir Khan', 'Sandrine Veysset', 'Doug Lefler', 'Dean Fleischer-Camp', 'Louise Archambault', 'Ameen Nayfeh', 'Tim Hunter', 'Ray Giarratana', 'François Marthouret', 'Wilson Yip', 'Bruce LaBruce', 'Heiki Ernits', 'Henri Lepage', 'Xu Haofeng', 'Michael Tollin', 'Hans Canosa', 'Dan Trachtenberg', 'Joshua Tunick', 'Chapour Haghighat', 'Lluis Danès', 'Richard Billingham', 'Cristèle Alves Meira', 'Matan Yair', 'Phil Joanou', 'Sophie Lorain', 'Paul Wright (II)', 'Jason Hreno', 'Travis Mathews', 'Seth Kearsley', 'Félix Dufour-Laperrière', 'Felipe Hirsch', 'Andrzej Zulawski', 'Árni Ólafur Ásgeirsson', 'Lauren Hadaway', 'Francis Glebas', 'Juan Vera', 'Leticia Tonos Paniagua', 'Daniel Robichaud', 'Antoine de Bary', 'Audrey Diwan', 'Darius Marder', 'Stefan Fjeldmark', 'Vincent Pluss', 'Gilles Bannier', "Michael O'Shea", 'Graham Annable', 'Spiros Stathoulopoulos', "Marcel L'Herbier", 'Clay Glen', 'Laura Samani', 'Joao César Monteiro', 'Antti Jokinen', 'Laurent Nègre', 'Hans Horn', 'Jalmari Helander', 'Claude Goretta', 'Céline Devaux', 'Jeanne Biras', 'Petra Collins', 'Dechen Roder', 'Aurel', 'Adam Green (VI)', 'Shreya Narayan', 'Bruno Lopez', 'Danilo Caputo', 'Nicolas Wackerbarth', 'Paul Leni', 'Lionel Delplanque', 'Jean-Gabriel Périot', 'Paul Tibbitt', 'Guillermo Arriaga', 'Elsa Diringer', 'Olivier Delahaye', 'David Carson', 'Mascha Halberstad', 'Alexandre Volkoff', 'Hoyt Yeatman', ' ...

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score, recall_score, roc_auc_score
print("######## accuracy_score : ")
print("TRAIN :",accuracy_score(y_train, y_pred_train))
print("TEST :",accuracy_score(y_test, y_pred_test))

print("######## precision_score : ")
print("TRAIN :",precision_score(y_train, y_pred_train))
print("TEST :",precision_score(y_test, y_pred_test))

print("######## recall_score : ")    
print("TRAIN :",recall_score(y_train, y_pred_train))
print("TEST :",recall_score(y_test, y_pred_test))

print("######## f1_score : ")
print("TRAIN :",f1_score(y_train, y_pred_train))
print("TEST :",f1_score(y_test, y_pred_test))

# %%
print("######## Mean Squared Error (MSE) : ")
print("TRAIN :", mean_squared_error(y_train, y_pred_train))
print("TEST :", mean_squared_error(y_test, y_pred_test))

# %%
rmse_train = np.sqrt(mean_squared_error(y_train, y_pred_train))
rmse_test = np.sqrt(mean_squared_error(y_test, y_pred_test))
print("######## Root Mean Squared Error (RMSE) : ")
print("TRAIN :", rmse_train)
print("TEST :", rmse_test)

# %%
print("######## Mean Absolute Error (MAE) : ")
print("TRAIN :", mean_absolute_error(y_train, y_pred_train))
print("TEST :", mean_absolute_error(y_test, y_pred_test))

# %%
print("######## R-squared (R2) : ")
print("TRAIN :", r2_score(y_train, y_pred_train))
print("TEST :", r2_score(y_test, y_pred_test))

# %%
# import matplotlib.pyplot as plt
# from sklearn.metrics import roc_curve, roc_auc_score


# # Calculate the ROC curve
# fpr, tpr, thresholds = roc_curve(y_test, y_pred_test)

# # Calculate the area under the ROC curve (AUC)
# auc = roc_auc_score(y_test, y_pred_test)

# # Plot the ROC curve
# plt.figure(figsize=(8, 6))
# plt.plot(fpr, tpr, label='ROC curve (AUC = {:.2f})'.format(auc))
# plt.plot([0, 1], [0, 1], 'k--', label='Random')
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('Receiver Operating Characteristic (ROC) Curve')
# plt.legend(loc='lower right')
# plt.show()

# print("######## roc_auc_score : ")    
# print("TRAIN :",roc_auc_score(y_train, y_pred_train))
# print("TEST :",roc_auc_score(y_test, y_pred_test))
