# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# %%
# import dataset
df = pd.read_csv('../feature engineering/data/dataset_gold.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10201 entries, 0 to 10200
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   titre                  10201 non-null  object
#  1   date                   9679 non-null   object
#  2   durée                  10201 non-null  float64
#  3   réalisateur            10201 non-null  object
#  4   distributeur           10201 non-null  object
#  5   acteurs                10201 non-null  object
#  6   nationalités           10201 non-null  object
#  7   langue_d_origine       10201 non-null  object
#  8   type_film              10201 non-null  object
#  9   annee_production       10201 non-null  int64
#  10  box_office_total       8347 non-null   float64
#  11  note_presse            10201 non-null  float64
#  12  note_spectateurs       10201 non-null  float64
#  13  nombre_article         9786 non-null   float64
#  14  description            9191 non-null   object
#  15  boxoffice              10201 non-null  int64
#  16  genres                 10201 non-null  object
#  17  awards                 10201 non-null  int64
#  18  nominations            10201 non-null  int64
#  19  nombre_acteurs_connus  10201 non-null  int64
#  20  acteurs_connus         10201 non-null  object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 1.6+ MB

# %%
df.columns
# Out:
# Index(['titre', 'date', 'durée', 'réalisateur', 'distributeur', 'acteurs',
#        'nationalités', 'langue_d_origine', 'type_film', 'annee_production',
#        'box_office_total', 'note_presse', 'note_spectateurs', 'nombre_article',
#        'description', 'boxoffice', 'genres', 'awards', 'nominations',
#        'nombre_acteurs_connus', 'acteurs_connus'],
#       dtype='object')

# %%
df.tail(10)
# Out:
#                                titre date       durée             réalisateur  \
# 10191              I Heard the Bells  NaN  103.340349             Joshua Enck
# 10192                      Crossover  NaN  103.340349  Preston A. Whitmore II
# 10193                   Papas chéris  NaN   86.000000            Cheryl Dunye
# 10194      Nothing Like the Holidays  NaN   99.000000        Alfredo De Villa
# 10195              A Madea Christmas  NaN  105.000000             Tyler Perry
# 10196         La Mujer de mi hermano  NaN   89.000000    Ricardo de Montreuil
# 10197                         Gracie  NaN   97.000000        Davis Guggenheim
# 10198     Keeping up with the Steins  NaN   99.000000          Scott Marshall
# 10199  Impractical Jokers: The Movie  NaN   93.000000            Chris Henchy
# 10200                Meet the Browns  NaN  103.340349             Tyler Perry
#
#       distributeur                                            acteurs  \
# 10191            -  ['Stephen Atherholt', 'Jonathan Blair', 'Rache...
# 10192            -  ['Anthony Mackie', 'Wesley Jonathan', 'Wayne B...
# 10193            -  ['Eddie Griffin', 'Anthony Anderson', 'Michael...
# 10194            -  ['Jay Hernandez', 'Melonie Diaz', 'Alfred Moli...
# 10195            -  ['Tyler Perry', 'Anna Maria Horsford', ' Larry...
# 10196            -  ['Bárbara Mori', 'Christian Meier', 'Manolo Ca...
# 10197            -  ['Carly Schroeder', 'Dermot Mulroney', 'Jesse ...
# 10198            -   ['Jami Gertz', 'Daryl Hannah', 'Garry Marshall']
# 10199            -        ['Brian Quinn', 'Joe Gatto', 'Sal Vulcano']
# 10200            -  ['Angela Bassett', 'Tyler Perry', 'Jenifer Lew...
#
#       nationalités langue_d_origine     type_film  annee_production  ...  \
# 10191       U.S.A.      ['Anglais']  Long-métrage              2022  ...
# 10192       U.S.A.      ['Anglais']  Long-métrage              2005  ...
# 10193       U.S.A.      ['Anglais']  Long-métrage              2004  ...
# 10194       U.S.A.      ['Anglais']  Long-métrage              2008  ...
# 10195       U.S.A.      ['Anglais']  Long-métrage              2013  ...
# 10196    Argentine     ['Espagnol']  Long-métrage              2005  ...
# 10197       U.S.A.      ['Anglais']  Long-métrage              2007  ...
# 10198       U.S.A.      ['Anglais']  Long-métrage              2006  ...
# 10199       U.S.A.      ['Anglais']  Long-métrage              2020  ...
# 10200       U.S.A.      ['Anglais']  Long-métrage              2008  ...
#
#        note_presse  note_spectateurs  nombre_article  \
# 10191      3.06052          3.016116             NaN
# 10192      2.40000          3.016116             1.0
# 10193      2.80000          3.016116             1.0
# 10194      2.60000          3.016116             2.0
# 10195      2.90000          3.016116             NaN
# 10196      3.00000          3.016116             NaN
# 10197      2.80000          3.016116             NaN
# 10198      2.60000          3.016116             1.0
# 10199      3.10000          3.016116             NaN
# 10200      2.50000          3.016116             1.0
#
#                                              description boxoffice  \
# 10191  Connu comme le poète de l'Amérique, Henry Wads...   2001603
# 10192  Un basketteur naturellement doué, Noah Cruise ...   3767567
# 10193  Trois jeunes hommes sont forcés d'entrer dans ...   7548819
# 10194  Une réunion de famille mouvementée, pendant le...   3531664
# 10195                                                NaN  16007634
# 10196  La monotonie gagne le couple de Zoe, jeune fem...   1018750
# 10197  En 1978, une adolescente dont le frère, as du ...   1355904
# 10198  Benjamin, un jeune garçon juif de 13 ans est s...    653723
# 10199  Quatre amis, Joe, Q, Murr et Sal, alias les Jo...   3545000
# 10200  Brenda est une mère célibataire qui vit à Chic...  20082809
#
#                                   genres awards  nominations  \
# 10191            ['Drame', 'Historique']      0            0
# 10192                ['Action', 'Drame']      0            0
# 10193                        ['Comédie']      0            0
# 10194             ['Comédie dramatique']      0            0
# 10195                        ['Comédie']      1            5
# 10196                          ['Drame']      0            0
# 10197                          ['Drame']      0            0
# 10198                        ['Comédie']      0            0
# 10199                        ['Comédie']      0            0
# 10200  ['Comédie dramatique', 'Romance']      0            0
#
#        nombre_acteurs_connus  acteurs_connus
# 10191                      0              []
# 10192                      0              []
# 10193                      0              []
# 10194                      0              []
# 10195                      0              []
# 10196                      0              []
# 10197                      0              []
# 10198                      0              []
# 10199                      0              []
# 10200                      0              []
#
# [10 rows x 21 columns]

# %%
# Utiliser la fonction "get_dummies" de pandas pour effectuer l'encodage
genres_encoded = df['genres'].str.join('|').str.get_dummies()

# Fusionner les colonnes encodées avec le DataFrame original
df_encoded = pd.concat([df, genres_encoded], axis=1).drop('genres', axis=1)

print(df_encoded)
# Out:
#                                     titre        date       durée  \
# 0               Super Mario Bros, le film  2023-05-04   92.000000
# 1      Les Vengeances de Maître Poutifard  2023-06-28   90.000000
# 2                         Des mains en or  2023-07-06   90.000000
# 3                            The Covenant  2023-06-23  123.000000
# 4                     Cléo, Melvil et moi  2023-05-07   73.000000
# ...                                   ...         ...         ...
# 10196              La Mujer de mi hermano         NaN   89.000000
# 10197                              Gracie         NaN   97.000000
# 10198          Keeping up with the Steins         NaN   99.000000
# 10199       Impractical Jokers: The Movie         NaN   93.000000
# 10200                     Meet the Browns         NaN  103.340349
#
#                         réalisateur                             distributeur  \
# 0                     Aaron Horvath  Universal Pictures International France
# 1      Pierre-François Martin-Laval                         UGC Distribution
# 2                 Isabelle Mergault                                Zinc Film
# 3                       Guy Ritchie                                        -
# 4                      Arnaud Viard             Moonlight Films Distribution
# ...                             ...                                      ...
# 10196          Ricardo de Montreuil                                        -
# 10197              Davis Guggenheim                                        -
# 10198                Scott Marshall                                        -
# 10199                  Chris Henchy                                        -
# 10200                   Tyler Perry                                        -
#
#                                                  acteurs     nationalités  \
# 0      ['Pierre Tessier', 'Chris Pratt', 'Jérémie Cov...           U.S.A.
# 1      ['Christian Clavier', 'Isabelle Nanty', 'Jenni...           France
# 2      ['Lambert Wilson', 'Josiane Balasko', 'Sylvie ...           France
# 3      ['Jake Gyllenhaal', 'Dar Salim', 'Alexander Lu...  Grande-Bretagne
# 4      ['Arnaud Viard', 'Marianne Denicourt', 'Romane...           France
# ...                                                  ...              ...
# 10196  ['Bárbara Mori', 'Christian Meier', 'Manolo Ca...        Argentine
# 10197  ['Carly Schroeder', 'Dermot Mulroney', 'Jesse ...           U.S.A.
# 10198   ['Jami Gertz', 'Daryl Hannah', 'Garry Marshall']           U.S.A.
# 10199        ['Brian Quinn', 'Joe Gatto', 'Sal Vulcano']           U.S.A.
# 10200  ['Angela Bassett', 'Tyler Perry', 'Jenifer Lew...           U.S.A.
#
#       langue_d_origine     type_film  annee_production  ...  r  s  t  u  v  w  \
# 0          ['Anglais']  Long-métrage              2023  ...  0  0  1  0  0  0
# 1         ['Français']  Long-métrage              2023  ...  0  0  0  0  0  0
# 2         ['Français']  Long-métrage              2023  ...  0  0  0  0  0  0
# 3          ['Anglais']  Long-métrage              2023  ...  1  0  1  1  0  0
# 4         ['Français']  Long-métrage              2023  ...  1  0  1  1  0  0
# ...                ...           ...               ...  ... .. .. .. .. .. ..
# 10196     ['Espagnol']  Long-métrage              2005  ...  1  0  0  0  0  0
# 10197      ['Anglais']  Long-métrage              2007  ...  1  0  0  0  0  0
# 10198      ['Anglais']  Long-métrage              2006  ...  0  0  0  0  0  0
# 10199      ['Anglais']  Long-métrage              2020  ...  0  0  0  0  0  0
# 10200      ['Anglais']  Long-métrage              2008  ...  1  0  1  1  0  0
#
#        x  y  é  û
# 0      0  0  1  0
# 1      0  0  1  0
# 2      0  0  1  0
# 3      0  0  0  0
# 4      0  0  1  0
# ...   .. .. .. ..
# 10196  0  0  0  0
# 10197  0  0  0  0
# 10198  0  0  1  0
# 10199  0  0  1  0
# 10200  0  0  1  0
#
# [10201 rows x 75 columns]

# %%
# from sklearn.model_selection import train_test_split
# X = df.drop(['boxoffice','date','acteurs','awards','box_office_total',
#        'description','nominations','note_presse','note_spectateurs', 'nombre_article','acteurs_connus'], axis=1)
# y = df['boxoffice']
# X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, shuffle=True, random_state=42)

# %%
# from sklearn.model_selection import train_test_split
# X = df.drop(['boxoffice','date','acteurs','awards','box_office_total',
#        'description','nominations','note_presse','note_spectateurs', 'nombre_article','acteurs_connus','titre','réalisateur','distributeur','langue_d_origine','genres'], axis=1)
# y = df['boxoffice']
# X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, shuffle=True, random_state=42)

# %%
# X

# %%
# X.isnull().sum()

# %%
# X.info()

# %%
# X.describe()

# %%
# # Import des bibliothèques
# from sklearn.pipeline import Pipeline
# from sklearn.preprocessing import OneHotEncoder, StandardScaler
# from sklearn.compose import ColumnTransformer
# from sklearn.linear_model import LinearRegression

# # Définir vos caractéristiques catégorielles et numériques
# # categorical_features = ['titre','réalisateur','distributeur','nationalités','langue_d_origine','type_film','genres']
# categorical_features = ['nationalités','type_film']

# numerical_features = ['durée', 'annee_production','nombre_acteurs_connus']

# # Créer le transformateur pour les caractéristiques catégorielles
# categorical_transformer = OneHotEncoder(sparse=True)

# # Créer le transformateur pour les caractéristiques numériques
# numerical_transformer = StandardScaler()

# # Créer le preprocessor en utilisant le ColumnTransformer pour gérer les deux types de caractéristiques
# preprocessor = ColumnTransformer(
#     transformers=[
#         ('cat', categorical_transformer, categorical_features),
#         ('num', numerical_transformer, numerical_features)
#     ],
#     remainder="passthrough" 
# )

# # Créer le modèle de régression linéaire
# lin_reg = LinearRegression()

# # Créer le pipeline en spécifiant les étapes dans l'ordre
# pipe = Pipeline([
#      ('preprocessor', preprocessor),
#      ('lin_reg', lin_reg)
# ])

# pipe

# %%
df.columns
# Out:
# Index(['titre', 'date', 'durée', 'réalisateur', 'distributeur', 'acteurs',
#        'nationalités', 'langue_d_origine', 'type_film', 'annee_production',
#        'box_office_total', 'note_presse', 'note_spectateurs', 'nombre_article',
#        'description', 'boxoffice', 'genres', 'awards', 'nominations',
#        'nombre_acteurs_connus', 'acteurs_connus'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
# X = df.drop(['boxoffice','date','acteurs','awards','box_office_total',
#        'description','nominations','note_presse','note_spectateurs', 'nombre_article','acteurs_connus','nationalités','langue_d_origine','genres','titre'], axis=1)

# Les colonnes à guarger:'titre','durée', 'réalisateur', 'distributeur','nationalités', 'langue_d_origine', 'type_film', 'annee_production','nombre_article','description', 
# 'genres','nombre_acteurs_connus',

X = df.drop(['boxoffice','date','acteurs','awards','box_office_total',
        'description','nominations','note_presse','note_spectateurs', 'nombre_article','acteurs_connus','titre'], axis=1)
y = df['boxoffice']
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, shuffle=True, random_state=42)

# %%
X.head(50)
# Out:
#     durée                   réalisateur  \
# 0    92.0                 Aaron Horvath
# 1    90.0  Pierre-François Martin-Laval
# 2    90.0             Isabelle Mergault
# 3   123.0                   Guy Ritchie
# 4    73.0                  Arnaud Viard
# 5    99.0             Matthias Luthardt
# 6    98.0                Angela Ottobah
# 7   123.0           Christian Schwochow
# 8    90.0               Bruno Podalydès
# 9   121.0             Martin Bourboulon
# 10  179.0               Martin Scorsese
# 11  138.0                    Fatih Akın
# 12  141.0               Louis Leterrier
# 13  120.0                     Paul Feig
# 14  125.0             Andrea Di Stefano
# 15   94.0             Manuel Abramovich
# 16  130.0                  Jordan Peele
# 17  103.0                  Julius Avery
# 18  113.0                 Ariel Zeitoun
# 19   98.0                    Tom George
# 20  114.0                  Dominik Moll
# 21   98.0                  Eric Lavaine
# 22  107.0                  Lisa Azuelos
# 23  122.0         Matt Bettinelli-Olpin
# 24   98.0              Clément Cogitore
# 25  105.0                   Lee Unkrich
# 26  105.0                   Lee Unkrich
# 27   95.0                   Gad Elmaleh
# 28   95.0                   Gad Elmaleh
# 29  106.0                           RZA
# 30  106.0                           RZA
# 31  126.0                    Saim Sadiq
# 32  134.0      Jonathan Goldstein (XII)
# 33  135.0                  Greta Gerwig
# 34  133.0                     Brad Bird
# 35   93.0                    Scott Beck
# 36  108.0                     Dany Boon
# 37  152.0             Christopher Nolan
# 38   86.0                  Nicolas Bary
# 39   93.0                   Gad Elmaleh
# 40  137.0                  Claire Denis
# 41  134.0                 Nicolas Bedos
# 42  101.0                Stéphane Brizé
# 43  126.0                   J.J. Abrams
# 44  139.0              Daniel Scheinert
# 45  118.0               Cédric Klapisch
# 46   89.0               Tristan Séguéla
# 47  127.0              Jean-Marc Vallée
# 48  152.0                Chris Columbus
# 49  148.0             Christopher Nolan
#
#                                       distributeur     nationalités  \
# 0          Universal Pictures International France           U.S.A.
# 1                                 UGC Distribution           France
# 2                                        Zinc Film           France
# 3                                                -  Grande-Bretagne
# 4                     Moonlight Films Distribution           France
# 5                            Pyramide Distribution           France
# 6                             Arizona Distribution           France
# 7   Happiness Distribution / Pyramide Distribution        Allemagne
# 8                                 UGC Distribution           France
# 9                                            Pathé           France
# 10                         Metropolitan FilmExport           U.S.A.
# 11                                           Pathé        Allemagne
# 12         Universal Pictures International France           U.S.A.
# 13                    Twentieth Century Fox France           U.S.A.
# 14         Universal Pictures International France           Italie
# 15                                 Epicentre Films        Argentine
# 16         Universal Pictures International France           U.S.A.
# 17                  Sony Pictures Releasing France           U.S.A.
# 18                         EuropaCorp Distribution           France
# 19                  The Walt Disney Company France  Grande-Bretagne
# 20                                   Haut et Court           France
# 21                                     StudioCanal           France
# 22                                           Pathé           France
# 23                       Paramount Pictures France           U.S.A.
# 24                           Diaphana Distribution           France
# 25                  The Walt Disney Company France           U.S.A.
# 26                  The Walt Disney Company France           U.S.A.
# 27                                     StudioCanal           France
# 28                                     StudioCanal           France
# 29                                  Netflix France           U.S.A.
# 30                                  Netflix France           U.S.A.
# 31                             Condor Distribution         Pakistan
# 32                       Paramount Pictures France           U.S.A.
# 33                  Sony Pictures Releasing France           U.S.A.
# 34                       Paramount Pictures France           U.S.A.
# 35                  Sony Pictures Releasing France           U.S.A.
# 36                                           Pathé           France
# 37                             Warner Bros. France           U.S.A.
# 38                 La Belle Company / Apollo Films           France
# 39                                     StudioCanal           France
# 40                                        Ad Vitam           France
# 41                                           Pathé           France
# 42                                      Rezo Films           France
# 43             United International Pictures (UIP)           U.S.A.
# 44                                      Pathé Live           U.S.A.
# 45                                     StudioCanal           France
# 46                            Gaumont Distribution           France
# 47                          L'Atelier Distribution           Canada
# 48                             Warner Bros. France           U.S.A.
# 49                             Warner Bros. France           U.S.A.
#
#                           langue_d_origine     type_film  annee_production  \
# 0                              ['Anglais']  Long-métrage              2023
# 1                             ['Français']  Long-métrage              2023
# 2                             ['Français']  Long-métrage              2023
# 3                              ['Anglais']  Long-métrage              2023
# 4                             ['Français']  Long-métrage              2023
# 5                ['Français', ' Allemand']  Long-métrage              2023
# 6                             ['Français']  Long-métrage              2021
# 7                             ['Allemand']  Long-métrage              2016
# 8                             ['Français']  Long-métrage              2023
# 9                             ['Français']  Long-métrage              2023
# 10                             ['Anglais']  Long-métrage              2013
# 11                            ['Allemand']  Long-métrage              2022
# 12                             ['Anglais']  Long-métrage              2023
# 13    ['Anglais', ' Français', ' Italien']  Long-métrage              2015
# 14                             ['Italien']  Long-métrage              2023
# 15                            ['Espagnol']  Long-métrage              2023
# 16                             ['Anglais']  Long-métrage              2022
# 17                             ['Anglais']  Long-métrage              2023
# 18                            ['Français']  Long-métrage              2013
# 19                             ['Anglais']  Long-métrage              2022
# 20                            ['Français']  Long-métrage              2022
# 21                            ['Français']  Long-métrage              2022
# 22                            ['Français']  Long-métrage              2008
# 23                             ['Anglais']  Long-métrage              2023
# 24                            ['Français']  Long-métrage              2022
# 25                             ['Anglais']  Long-métrage              2017
# 26                             ['Anglais']  Long-métrage              2017
# 27                            ['Français']  Long-métrage              2008
# 28                            ['Français']  Long-métrage              2008
# 29                             ['Anglais']  Long-métrage              2017
# 30                             ['Anglais']  Long-métrage              2017
# 31                                ['Urdu']  Long-métrage              2022
# 32                             ['Anglais']  Long-métrage              2023
# 33                             ['Anglais']  Long-métrage              2019
# 34                             ['Anglais']  Long-métrage              2011
# 35                             ['Anglais']  Long-métrage              2023
# 36                            ['Français']  Long-métrage              2014
# 37                             ['Anglais']  Long-métrage              2008
# 38                            ['Français']  Long-métrage              2016
# 39                            ['Français']  Long-métrage              2022
# 40                ['Anglais', ' Français']  Long-métrage              2022
# 41                            ['Français']  Long-métrage              2021
# 42                            ['Français']  Long-métrage              2009
# 43                             ['Anglais']  Long-métrage              2006
# 44  ['Anglais', ' Cantonais', ' Mandarin']  Long-métrage              2022
# 45                            ['Français']  Long-métrage              2022
# 46                            ['Français']  Long-métrage              2023
# 47                            ['Français']  Long-métrage              2005
# 48                             ['Anglais']  Long-métrage              2001
# 49                ['Anglais', ' Japonais']  Long-métrage              2010
#
#                                                genres  nombre_acteurs_connus
# 0                 ['Animation', 'Comédie', 'Famille']                      1
# 1                              ['Comédie', 'Famille']                      1
# 2                                         ['Comédie']                      2
# 3                    ['Action', 'Guerre', 'Thriller']                      1
# 4                              ['Comédie dramatique']                      0
# 5                  ['Drame', 'Historique', 'Romance']                      0
# 6                                           ['Drame']                      0
# 7                                 ['Biopic', 'Drame']                      0
# 8                                         ['Comédie']                      1
# 9                          ['Aventure', 'Historique']                      3
# 10                                ['Biopic', 'Drame']                      2
# 11                     ['Biopic', 'Drame', 'Musical']                      0
# 12                                         ['Action']                      2
# 13                              ['Action', 'Comédie']                      2
# 14                                       ['Thriller']                      0
# 15                                          ['Drame']                      0
# 16  ['Epouvante-horreur', 'Science fiction', 'Thri...                      0
# 17     ['Biopic', 'Epouvante-horreur', 'Fantastique']                      1
# 18                         ['Aventure', 'Historique']                      1
# 19                            ['Comédie', 'Policier']                      0
# 20                           ['Policier', 'Thriller']                      0
# 21                                        ['Comédie']                      2
# 22                                        ['Comédie']                      1
# 23                              ['Epouvante-horreur']                      0
# 24                                          ['Drame']                      0
# 25            ['Animation', 'Famille', 'Fantastique']                      0
# 26            ['Animation', 'Famille', 'Fantastique']                      0
# 27                                        ['Comédie']                      0
# 28                                        ['Comédie']                      0
# 29                      ['Comédie musicale', 'Drame']                      0
# 30                      ['Comédie musicale', 'Drame']                      0
# 31                               ['Drame', 'Romance']                      0
# 32                        ['Aventure', 'Fantastique']                      1
# 33                               ['Drame', 'Romance']                      1
# 34               ['Action', 'Espionnage', 'Thriller']                      2
# 35          ['Action', 'Science fiction', 'Thriller']                      1
# 36                                        ['Comédie']                      2
# 37                             ['Action', 'Thriller']                      1
# 38                             ['Comédie', 'Famille']                      2
# 39                                        ['Comédie']                      0
# 40                   ['Drame', 'Romance', 'Thriller']                      0
# 41                             ['Comédie dramatique']                      2
# 42                               ['Drame', 'Romance']                      2
# 43               ['Action', 'Espionnage', 'Thriller']                      1
# 44  ['Action', 'Arts Martiaux', 'Comédie', 'Drame'...                      0
# 45         ['Comédie', 'Comédie dramatique', 'Drame']                      0
# 46                                        ['Comédie']                      1
# 47                                          ['Drame']                      0
# 48             ['Aventure', 'Famille', 'Fantastique']                      2
# 49                    ['Science fiction', 'Thriller']                      3

# %%
# Import des bibliothèques
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression

# Définir vos caractéristiques catégorielles et numériques
# categorical_features = ['titre','réalisateur','distributeur','nationalités','langue_d_origine','type_film','genres']
categorical_features = ['réalisateur','distributeur','type_film']

numerical_features = ['durée', 'annee_production','nombre_acteurs_connus']

# Créer le transformateur pour les caractéristiques catégorielles
categorical_transformer = OneHotEncoder(sparse=True)

# Créer le transformateur pour les caractéristiques numériques
numerical_transformer = StandardScaler()

# Créer le preprocessor en utilisant le ColumnTransformer pour gérer les deux types de caractéristiques
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', categorical_transformer, categorical_features),
        ('num', numerical_transformer, numerical_features)
    ],
    remainder="passthrough" 
)

# Créer le modèle de régression linéaire
lin_reg = LinearRegression()

# Créer le pipeline en spécifiant les étapes dans l'ordre
pipe = Pipeline([
     ('preprocessor', preprocessor),
     ('lin_reg', lin_reg)
])

pipe
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(sparse=True),
#                                                   ['réalisateur',
#                                                    'distributeur',
#                                                    'type_film']),
#                                                  ('num', StandardScaler(),
#                                                   ['durée', 'annee_production',
#                                                    'nombre_acteurs_connus'])])),
#                 ('lin_reg', LinearRegression())])

# %%
# Ajuster (fit) le pipeline avec les données d'entraînement
pipe.fit(X_train, y_train)
# Out:
# /home/apprenant/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/compose/_column_transformer.py in ?(self, Xs)
#     849                 ]
#     850             except ValueError as e:
# --> 851                 raise ValueError(
#     852                     "For a sparse output, all columns should "
#
# ~/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/compose/_column_transformer.py in ?(.0)
#     846     def _hstack(self, Xs):
# --> 847         """Stacks Xs horizontally.
#     848
#
# ~/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/utils/validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     916                 else:
#     917                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# --> 918             except ComplexWarning as complex_warning:
#     919                 raise ValueError(
#
# ~/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/utils/_array_api.py in ?(array, dtype, order, copy, xp)
#     378             array = numpy.array(array, order=order, dtype=dtype)
#     379         else:
# --> 380             array = numpy.asarray(array, order=order, dtype=dtype)
#     381
#
# ~/miniconda3/envs/myenv/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, dtype)
#    1996     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#    1997         values = self._values
# -> 1998         arr = np.asarray(values, dtype=dtype)
#    1999         if (
#
# ValueError: could not convert string to float: 'U.S.A.'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[207], line 2
#       1 # Ajuster (fit) le pipeline avec les données d'entraînement
# ----> 2 pipe.fit(X_train, y_train)
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/pipeline.py:416, in Pipeline.fit(self, X, y, **fit_params)
#     390 """Fit the model.
#     391
#     392 Fit all the transformers one after the other and transform the
#    (...)
#     413     Pipeline with fitted steps.
#     414 """
#     415 fit_params_steps = self._check_fit_params(**fit_params)
# --> 416 Xt = self._fit(X, y, **fit_params_steps)
#     417 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     418     if self._final_estimator != "passthrough":
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/pipeline.py:370, in Pipeline._fit(self, X, y, **fit_params_steps)
#     368     cloned_transformer = clone(transformer)
#     369 # Fit or load from cache the current transformer
# --> 370 X, fitted_transformer = fit_transform_one_cached(
#     371     cloned_transformer,
#     372     X,
#     373     y,
#     374     None,
#     375     message_clsname="Pipeline",
#     376     message=self._log_message(step_idx),
#     377     **fit_params_steps[name],
#     378 )
#     379 # Replace the transformer of the step with the fitted
#     380 # transformer. This is necessary when loading the transformer
#     381 # from the cache.
#     382 self.steps[step_idx] = (name, fitted_transformer)
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/joblib/memory.py:353, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     352 def __call__(self, *args, **kwargs):
# --> 353     return self.func(*args, **kwargs)
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/pipeline.py:950, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     948 with _print_elapsed_time(message_clsname, message):
#     949     if hasattr(transformer, "fit_transform"):
# --> 950         res = transformer.fit_transform(X, y, **fit_params)
#     951     else:
#     952         res = transformer.fit(X, y, **fit_params).transform(X)
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/utils/_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return_tuple = (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/compose/_column_transformer.py:767, in ColumnTransformer.fit_transform(self, X, y)
#     764 self._validate_output(Xs)
#     765 self._record_output_indices(Xs)
# --> 767 return self._hstack(list(Xs))
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/compose/_column_transformer.py:851, in ColumnTransformer._hstack(self, Xs)
#     846         converted_Xs = [
#     847             check_array(X, accept_sparse=True, force_all_finite=False)
#     848             for X in Xs
#     849         ]
#     850     except ValueError as e:
# --> 851         raise ValueError(
#     852             "For a sparse output, all columns should "
#     853             "be a numeric or convertible to a numeric."
#     854         ) from e
#     856     return sparse.hstack(converted_Xs).tocsr()
#     857 else:
#
# ValueError: For a sparse output, all columns should be a numeric or convertible to a numeric.

# %%
# Maintenant que le pipeline est ajusté, vous pouvez faire des prédictions
y_pred_train = pipe.predict(X_train)
y_pred_test = pipe.predict(X_test)
y_pred_test
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[100], line 3
#       1 # Maintenant que le pipeline est ajusté, vous pouvez faire des prédictions
#       2 y_pred_train = pipe.predict(X_train)
# ----> 3 y_pred_test = pipe.predict(X_test)
#       4 y_pred_test
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/pipeline.py:507, in Pipeline.predict(self, X, **predict_params)
#     505 Xt = X
#     506 for _, name, transform in self._iter(with_final=False):
# --> 507     Xt = transform.transform(Xt)
#     508 return self.steps[-1][1].predict(Xt, **predict_params)
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/utils/_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return_tuple = (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/compose/_column_transformer.py:816, in ColumnTransformer.transform(self, X)
#     811 else:
#     812     # ndarray was used for fitting or transforming, thus we only
#     813     # check that n_features_in_ is consistent
#     814     self._check_n_features(X, reset=False)
# --> 816 Xs = self._fit_transform(
#     817     X,
#     818     None,
#     819     _transform_one,
#     820     fitted=True,
#     821     column_as_strings=fit_dataframe_and_transform_dataframe,
#     822 )
#     823 self._validate_output(Xs)
#     825 if not Xs:
#     826     # All transformers are None
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/compose/_column_transformer.py:670, in ColumnTransformer._fit_transform(self, X, y, func, fitted, column_as_strings)
#     664 transformers = list(
#     665     self._iter(
#     666         fitted=fitted, replace_strings=True, column_as_strings=column_as_strings
#     667     )
#     668 )
#     669 try:
# --> 670     return Parallel(n_jobs=self.n_jobs)(
#     671         delayed(func)(
#     672             transformer=clone(trans) if not fitted else trans,
#     673             X=_safe_indexing(X, column, axis=1),
#     674             y=y,
#     675             weight=weight,
#     676             message_clsname="ColumnTransformer",
#     677             message=self._log_message(name, idx, len(transformers)),
#     678         )
#     679         for idx, (name, trans, column, weight) in enumerate(transformers, 1)
#     680     )
#     681 except ValueError as e:
#     682     if "Expected 2D array, got 1D array instead" in str(e):
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/utils/parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/joblib/parallel.py:1855, in Parallel.__call__(self, iterable)
#    1853     output = self._get_sequential_output(iterable)
#    1854     next(output)
# -> 1855     return output if self.return_generator else list(output)
#    1857 # Let's create an ID that uniquely identifies the current call. If the
#    1858 # call is interrupted early and that the same instance is immediately
#    1859 # re-used, this id will be used to prevent workers that were
#    1860 # concurrently finalizing a task from the previous call to run the
#    1861 # callback.
#    1862 with self._lock:
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/joblib/parallel.py:1784, in Parallel._get_sequential_output(self, iterable)
#    1782 self.n_dispatched_batches += 1
#    1783 self.n_dispatched_tasks += 1
# -> 1784 res = func(*args, **kwargs)
#    1785 self.n_completed_tasks += 1
#    1786 self.print_progress()
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/utils/parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/pipeline.py:933, in _transform_one(transformer, X, y, weight, **fit_params)
#     932 def _transform_one(transformer, X, y, weight, **fit_params):
# --> 933     res = transformer.transform(X)
#     934     # if we have a weight for this transformer, multiply output
#     935     if weight is None:
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/utils/_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return_tuple = (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:1016, in OneHotEncoder.transform(self, X)
#    1011 # validation of X happens in _check_X called by _transform
#    1012 warn_on_unknown = self.drop is not None and self.handle_unknown in {
#    1013     "ignore",
#    1014     "infrequent_if_exist",
#    1015 }
# -> 1016 X_int, X_mask = self._transform(
#    1017     X,
#    1018     handle_unknown=self.handle_unknown,
#    1019     force_all_finite="allow-nan",
#    1020     warn_on_unknown=warn_on_unknown,
#    1021 )
#    1023 n_samples, n_features = X_int.shape
#    1025 if self._drop_idx_after_grouping is not None:
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:199, in _BaseEncoder._transform(self, X, handle_unknown, force_all_finite, warn_on_unknown, ignore_category_indices)
#     194 if handle_unknown == "error":
#     195     msg = (
#     196         "Found unknown categories {0} in column {1}"
#     197         " during transform".format(diff, i)
#     198     )
# --> 199     raise ValueError(msg)
#     200 else:
#     201     if warn_on_unknown:
#
# ValueError: Found unknown categories ['Lana Wachowski', 'José Miguel Ribeiro', 'Wolfgang Liebeneiner', 'Richard Glatzer', 'Joël Seria', 'Bogdan Mirică', 'Gérome Barry', 'Won-Chan Hong', 'Ada Loueilh', 'Fabio Mollo', 'Ladislas Chollat', 'Christopher Spencer', 'Yang Huilong', 'Bryan Spicer', 'Roger Delattre', 'Patrick Bouchitey', 'Peter Masterson', 'Fiona Gordon', 'Léopold Legrand', 'Thomas Szabo', 'Bernard Mazauric', 'Natasha Arthy', 'Vincent Patar', 'Bigas Luna', 'Peter Ho-Sun Chan', 'Jonathan Mostow', 'Daniel Colas', 'Roger Corman', 'Ameen Nayfeh', 'Mascha Halberstad', 'David Charbonier', 'Peter Bratt', 'Kevin Kölsch', 'Wolfgang Fischer', 'Cordula Kablitz-Post', 'Hannes Holm', 'Anna Rose Holmer', 'Dan Curtis', 'Annie Molin Vasseur', 'Crystal Moselle', 'Tamra Davis', 'Jure Pavlović', 'Jeanne Quibel', 'Brent Cote', 'Emmanuelle Nicot', 'Maurice Delbez', 'Phil Jutzi', 'Emma Holly Jones', 'Lars Klevberg', 'Perry Lang', 'Rasmus Kloster Bro', 'Andrew Legge', 'Edouard Molinaro', 'Daouda Coulibaly (II)', 'Steve Buscemi', 'Ruth Borgobello', 'Daniel Brühl', 'Gauri Shinde', 'Gene Stupnitsky', 'Joe Dante', 'Franck Ekinci', 'Alexandre Volkoff', 'Antoine Charreyron', 'Jonathan Desoindre', 'Frédéric Baillif', "Salvatore D'Agostini", 'Jill Culton', 'Zep', 'Navot Papushado', 'Espen Sandberg', 'Carolina Cavalli', 'Erick Malabry', 'Paul Lefèvre', 'Douglas Aarniokoski', 'David Nixon', 'Laetitia Masson', 'Gene Fallaize', 'Claire Simon', 'Christian Ryltenius', 'Charlotte Vandermeersch', 'Sung-ho Park', 'Andrew Douglas', 'Rocco Papaleo', 'Miransha Naik', 'Brad Silberling', 'Mort Nathan', 'Jim Isaac', 'Maxime Martinot', 'Giordano Gederlini', 'Michela Occhipinti', 'Elite Zexer', 'Nicolas Wackerbarth', 'Christophe Leclaire', 'Robert Harmon', 'Stéphane Cazes', 'Andreï Kravchuk', 'Jean-Daniel Verhaeghe', 'Amman Abbasi', 'Yusuke Hirota', 'Marco Martins', 'Georges Lautner', 'Shawkat Amin Korki', 'Giulio Ricciarelli', 'Rok Bicek', 'Zeina Durra', 'Dax Shepard', 'David Raynr', 'Javier Fuentes-León', 'Hoyt Yeatman', 'Christophe Van Rompaey', 'Olivier Meys', 'Camille Vidal-Naquet', 'Terence Nance', 'Jonathan Nossiter', 'Maxime Roy', 'Blerta Basholli', 'Mushon Salmona', 'Rohit Shetty', 'Christian François', 'Andréa Sedlackova', 'Mina Mileva', 'Romain Laguna', 'Kyle Balda', 'Frank Urson', 'Irene Jouannet', 'Bob Swaim', 'Stefano Lodovichi', 'Patrick Huard', 'Richard Wong', 'Luis Mandoki', 'J.D. Dillard', 'Rob Pritts', 'Jens Lien', 'Jonas Åkerlund', 'Bora Dagtekin', 'Sylvain Labrosse', 'Pascal Tessaud', 'Michael Winner', 'Christopher Murray', 'Tom George', 'Felipe Hirsch', 'Gary Chapman', 'Tomohiko Itō', 'Stéphane Meunier', 'Juan José Lozano', 'Souheil Ben-Barka', 'João Canijo', 'Yong-hoon Kim', 'Emmanuel Courcol', 'Andrea Bagney', 'George Nolfi', 'C.B. Harding', 'Jean-Paul Carrère', 'Benjamin de Lajarte', 'Michael Patrick King', 'Emmanuelle Millet', 'Antoinette Beumer', 'Hu Bo', 'Francesca Archibugi', 'Jalmari Helander', 'Sheldon Larry', 'Michael Lannan', 'Loveleen Tandan', 'Laurent Chouchan', 'Luchino Visconti', 'Siddharth Anand', 'Christophe Campos', 'Gregg Araki', 'Diablo Cody', 'Mikhil Musale', 'Manu Payet', 'Nathalie Álvarez Mesén', 'Aaron Kaufman', 'Jérôme Cohen-Olivar', 'Michael Hegner', 'José Luis Rugeles', 'Thomas Kaiser', 'Philippe Mechelen', 'Fernando Lebrija', 'Lisa Bierwirth', 'Gustav Deutsch', 'Christopher Erskin', 'Ismaël El Iraki', 'Josée Dayan', 'Alexis Lloyd', 'Pascale Bailly', 'Henry Hobson', 'Friederike Jehn', 'Seth Kearsley', 'Esmir Filho', 'Marco Danieli', 'Gilles Martinerie', 'Dinara Drukarova', 'Adele Lim', 'Andy Guérif', 'Alejandro Jodorowsky', 'Zu Feng', 'Bruno Rolland', 'Gerard McMurray', 'Clay Tarver', 'Alice Zeniter', 'Jesper Ganslandt', 'Jody Hill', 'Cedric Nicolas-Troyan', 'Xiaogang Feng', 'Adriàn Garcia', 'Duane Hopkins', 'Terry Zwigoff', 'Bob Walker', 'Don Hall', 'Carlota Pereda', 'Judith Kaufmann', 'Joséphine de Meaux', 'Stéphane Freiss', 'Alexis Dos Santos', 'Marcelo Caetano', 'Le-Van Kiet', 'Ash Brannon', 'Laurent Micheli', 'Die ...

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score, recall_score, roc_auc_score
print("######## accuracy_score : ")
print("TRAIN :",accuracy_score(y_train, y_pred_train))
print("TEST :",accuracy_score(y_test, y_pred_test))

print("######## precision_score : ")
print("TRAIN :",precision_score(y_train, y_pred_train))
print("TEST :",precision_score(y_test, y_pred_test))

print("######## recall_score : ")    
print("TRAIN :",recall_score(y_train, y_pred_train))
print("TEST :",recall_score(y_test, y_pred_test))

print("######## f1_score : ")
print("TRAIN :",f1_score(y_train, y_pred_train))
print("TEST :",f1_score(y_test, y_pred_test))

# %%
print("######## Mean Squared Error (MSE) : ")
print("TRAIN :", mean_squared_error(y_train, y_pred_train))
print("TEST :", mean_squared_error(y_test, y_pred_test))

# %%
rmse_train = np.sqrt(mean_squared_error(y_train, y_pred_train))
rmse_test = np.sqrt(mean_squared_error(y_test, y_pred_test))
print("######## Root Mean Squared Error (RMSE) : ")
print("TRAIN :", rmse_train)
print("TEST :", rmse_test)

# %%
print("######## Mean Absolute Error (MAE) : ")
print("TRAIN :", mean_absolute_error(y_train, y_pred_train))
print("TEST :", mean_absolute_error(y_test, y_pred_test))

# %%
print("######## R-squared (R2) : ")
print("TRAIN :", r2_score(y_train, y_pred_train))
print("TEST :", r2_score(y_test, y_pred_test))

# %%
# import matplotlib.pyplot as plt
# from sklearn.metrics import roc_curve, roc_auc_score


# # Calculate the ROC curve
# fpr, tpr, thresholds = roc_curve(y_test, y_pred_test)

# # Calculate the area under the ROC curve (AUC)
# auc = roc_auc_score(y_test, y_pred_test)

# # Plot the ROC curve
# plt.figure(figsize=(8, 6))
# plt.plot(fpr, tpr, label='ROC curve (AUC = {:.2f})'.format(auc))
# plt.plot([0, 1], [0, 1], 'k--', label='Random')
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('Receiver Operating Characteristic (ROC) Curve')
# plt.legend(loc='lower right')
# plt.show()

# print("######## roc_auc_score : ")    
# print("TRAIN :",roc_auc_score(y_train, y_pred_train))
# print("TEST :",roc_auc_score(y_test, y_pred_test))
