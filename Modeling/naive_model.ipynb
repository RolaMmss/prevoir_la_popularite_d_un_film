# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# %%
# import dataset
df = pd.read_csv('../feature engineering/data/dataset_gold.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3948 entries, 0 to 3947
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   titre                  3948 non-null   object
#  1   date                   3948 non-null   object
#  2   genre                  3948 non-null   object
#  3   durée                  3948 non-null   float64
#  4   réalisateur            3948 non-null   object
#  5   distributeur           3948 non-null   object
#  6   acteurs                3948 non-null   object
#  7   nationalités           3948 non-null   object
#  8   langue_d_origine       3931 non-null   object
#  9   type_film              3948 non-null   object
#  10  annee_production       3948 non-null   int64
#  11  box_office_total       3369 non-null   float64
#  12  note_presse            3948 non-null   float64
#  13  note_spectateurs       3948 non-null   float64
#  14  nombre_article         3882 non-null   float64
#  15  description            3544 non-null   object
#  16  boxoffice              3948 non-null   int64
#  17  awards                 3948 non-null   int64
#  18  nominations            3948 non-null   int64
#  19  nombre_acteurs_connus  3948 non-null   int64
#  20  acteurs_connus         3948 non-null   object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 647.8+ KB

# %%
df.columns
# Out:
# Index(['titre', 'date', 'genre', 'durée', 'réalisateur', 'distributeur',
#        'acteurs', 'nationalités', 'langue_d_origine', 'type_film',
#        'annee_production', 'box_office_total', 'note_presse',
#        'note_spectateurs', 'nombre_article', 'description', 'boxoffice',
#        'awards', 'nominations', 'nombre_acteurs_connus', 'acteurs_connus'],
#       dtype='object')

# %%
df.tail(10)
# Out:
#                                                   titre        date  \
# 3938                                   Joue contre joue  2017-04-01
# 3939  Il cuore grande delle ragazze (Le Grand Coeur ...  2012-02-05
# 3940                               La venta del paraíso  2013-03-04
# 3941                                     Le Grand Perdu  2018-12-09
# 3942                                     Off White Lies  2013-12-06
# 3943                                    Beijing Stories  2016-06-01
# 3944                                       Sao Bernardo  2014-11-06
# 3945                                     Uttama Villain  2015-01-05
# 3946                  Gamperaliya changement au village  2009-06-05
# 3947                           Le Maître du déguisement  2003-07-10
#
#                          genre  durée              réalisateur  \
# 3938                   Romance   63.0        Cyrille Benvenuto
# 3939                   Comédie   85.0               Pupi Avati
# 3940             Comédie,Drame  102.0   Emilio Ruiz Barrachina
# 3941                     Drame   78.0  Avénarius d’Ardronville
# 3942        Comédie dramatique   86.0               Maya Kenig
# 3943                     Drame   75.0             Pengfei Song
# 3944                     Drame  113.0            Leon Hirszman
# 3945                   Comédie  172.0           Ramesh Aravind
# 3946                     Drame  108.0      Lester James Peries
# 3947  Aventure,Comédie,Famille   80.0      Perry Andelin Blake
#
#                      distributeur  \
# 3938               Elévation-Prod
# 3939         Les Films de l'Astre
# 3940                 Floris Films
# 3941  Cinéma Saint-André des Arts
# 3942         Solaris Distribution
# 3943           Urban Distribution
# 3944        Les Films du Paradoxe
# 3945                  Aanna Films
# 3946                      inconnu
# 3947       Columbia TriStar Films
#
#                                                 acteurs nationalités  \
# 3938  ['Jenny Lepage', 'Julie Joubert', 'Manuel Mart...       France
# 3939  ['Cesare Cremonini', 'Micaela Ramazzotti', 'Gi...       Italie
# 3940  ['Ana Claudia Talancón', 'William Miller', 'Ju...      Espagne
# 3941  ['Serge Blazevic', 'Nicolas de Lavergne', 'Erw...       France
# 3942      ['Gurt Bentvich', 'Elya Inbar', 'Tzahi Grad']       Israël
# 3943             ['Ze Ying', 'Luo Wenjie', 'Zhao Fuyu']        Chine
# 3944  ['Rodolfo Arena', 'Othon Bastos', 'Luiz Carlos...       Brésil
# 3945    ['Kamal Haasan', 'Rajesh M. Selva', ' Jayaram']         Inde
# 3946  ['Punya Hiendeniya', 'Henry Jayasena', 'Wickre...    Sri Lanka
# 3947    ['Dana Carvey', 'Maria Canals', 'Austin Wolff']       U.S.A.
#
#      langue_d_origine     type_film  ...  box_office_total  note_presse  \
# 3938         Français  Long-métrage  ...              16.0          3.3
# 3939          Italien  Long-métrage  ...             729.0          2.1
# 3940         Espagnol  Long-métrage  ...             168.0          2.0
# 3941         Français  Long-métrage  ...             148.0          3.2
# 3942           Hebreu  Long-métrage  ...            1350.0          3.6
# 3943         Mandarin  Long-métrage  ...            2507.0          3.1
# 3944        Portugais  Long-métrage  ...             107.0          4.3
# 3945           Tamoul  Long-métrage  ...             157.0          3.1
# 3946            Autre  Long-métrage  ...            1289.0          4.5
# 3947          Anglais  Long-métrage  ...               NaN          1.5
#
#       note_spectateurs  nombre_article  \
# 3938          3.016116             NaN
# 3939          2.200000             8.0
# 3940          2.600000             8.0
# 3941          3.016116             7.0
# 3942          3.200000             8.0
# 3943          2.900000            12.0
# 3944          2.400000             3.0
# 3945          3.016116             2.0
# 3946          3.300000             6.0
# 3947          3.016116             6.0
#
#                                             description boxoffice  awards  \
# 3938  Il y a des gens qui se ressemblent, qui aiment...        20       0
# 3939  Début des années 30, dans un petit village du ...      1218       0
# 3940  Aura María, une jeune fille mexicaine quitte s...       332       0
# 3941  Film métaphorique où un capitaine de navire,  ...       153       0
# 3942  Libby débarque à Tel Aviv pour retrouver son p...      1650       0
# 3943  Beijing. 23 millions d’habitants et une croiss...      3262       0
# 3944                                                NaN       156       0
# 3945  Au 8ème siècle, quelque part en Inde, Uttaman ...      1805       0
# 3946  Amoureuse de l'instituteur, une jeune femme es...      1663       0
# 3947  Pistachio Disguisey, serveur dans le restauran...  12554650       0
#
#       nominations  nombre_acteurs_connus  acteurs_connus
# 3938            0                      0              []
# 3939            2                      0              []
# 3940            0                      0              []
# 3941            0                      0              []
# 3942            0                      0              []
# 3943            0                      0              []
# 3944            0                      0              []
# 3945            0                      0              []
# 3946            0                      0              []
# 3947            0                      0              []
#
# [10 rows x 21 columns]

# %%
# Utiliser la fonction "get_dummies" de pandas pour effectuer l'encodage
genres_encoded = df['genre'].str.join('|').str.get_dummies()

# Fusionner les colonnes encodées avec le DataFrame original
df_encoded = pd.concat([df, genres_encoded], axis=1).drop('genre', axis=1)

# %%
df_encoded.head(5)
# Out:
#                        titre        date  durée          réalisateur  \
# 0  Super Mario Bros, le film  2023-05-04   92.0        Aaron Horvath
# 1            Des mains en or  2023-07-06   90.0    Isabelle Mergault
# 2        Cléo, Melvil et moi  2023-05-07   73.0         Arnaud Viard
# 3                      Luise  2023-05-07   99.0    Matthias Luthardt
# 4                      Paula  2017-01-03  123.0  Christian Schwochow
#
#                                      distributeur  \
# 0         Universal Pictures International France
# 1                                       Zinc Film
# 2                    Moonlight Films Distribution
# 3                           Pyramide Distribution
# 4  Happiness Distribution / Pyramide Distribution
#
#                                              acteurs nationalités  \
# 0  ['Pierre Tessier', 'Chris Pratt', 'Jérémie Cov...       U.S.A.
# 1  ['Lambert Wilson', 'Josiane Balasko', 'Sylvie ...       France
# 2  ['Arnaud Viard', 'Marianne Denicourt', 'Romane...       France
# 3  ['Luise Aschenbrenner', 'Christa Théret', 'Leo...       France
# 4  ['Carla Juri', 'Albrecht Schuch', 'Roxane Duran']    Allemagne
#
#   langue_d_origine     type_film  annee_production  ...  q  r  s  t  u  v  w  \
# 0          Anglais  Long-métrage              2023  ...  0  0  0  1  0  0  0
# 1         Français  Long-métrage              2023  ...  0  0  0  0  0  0  0
# 2         Français  Long-métrage              2023  ...  1  1  0  1  1  0  0
# 3         Français  Long-métrage              2023  ...  1  1  1  1  1  0  0
# 4         Allemand  Long-métrage              2016  ...  0  1  0  0  0  0  0
#
#    x  y  é
# 0  0  0  1
# 1  0  0  1
# 2  0  0  1
# 3  0  0  0
# 4  0  0  0
#
# [5 rows x 61 columns]

# %%
# from sklearn.model_selection import train_test_split
# X = df.drop(['boxoffice','date','acteurs','awards','box_office_total',
#        'description','nominations','note_presse','note_spectateurs', 'nombre_article','acteurs_connus'], axis=1)
# y = df['boxoffice']
# X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, shuffle=True, random_state=42)

# %%
# from sklearn.model_selection import train_test_split
# X = df.drop(['boxoffice','date','acteurs','awards','box_office_total',
#        'description','nominations','note_presse','note_spectateurs', 'nombre_article','acteurs_connus','titre','réalisateur','distributeur','langue_d_origine','genres'], axis=1)
# y = df['boxoffice']
# X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, shuffle=True, random_state=42)

# %%
# X

# %%
# X.isnull().sum()

# %%
# X.info()

# %%
# X.describe()

# %%
# # Import des bibliothèques
# from sklearn.pipeline import Pipeline
# from sklearn.preprocessing import OneHotEncoder, StandardScaler
# from sklearn.compose import ColumnTransformer
# from sklearn.linear_model import LinearRegression

# # Définir vos caractéristiques catégorielles et numériques
# # categorical_features = ['titre','réalisateur','distributeur','nationalités','langue_d_origine','type_film','genres']
# categorical_features = ['nationalités','type_film']

# numerical_features = ['durée', 'annee_production','nombre_acteurs_connus']

# # Créer le transformateur pour les caractéristiques catégorielles
# categorical_transformer = OneHotEncoder(sparse=True)

# # Créer le transformateur pour les caractéristiques numériques
# numerical_transformer = StandardScaler()

# # Créer le preprocessor en utilisant le ColumnTransformer pour gérer les deux types de caractéristiques
# preprocessor = ColumnTransformer(
#     transformers=[
#         ('cat', categorical_transformer, categorical_features),
#         ('num', numerical_transformer, numerical_features)
#     ],
#     remainder="passthrough" 
# )

# # Créer le modèle de régression linéaire
# lin_reg = LinearRegression()

# # Créer le pipeline en spécifiant les étapes dans l'ordre
# pipe = Pipeline([
#      ('preprocessor', preprocessor),
#      ('lin_reg', lin_reg)
# ])

# pipe

# %%
df.columns
# Out:
# Index(['titre', 'date', 'genre', 'durée', 'réalisateur', 'distributeur',
#        'acteurs', 'nationalités', 'langue_d_origine', 'type_film',
#        'annee_production', 'box_office_total', 'note_presse',
#        'note_spectateurs', 'nombre_article', 'description', 'boxoffice',
#        'awards', 'nominations', 'nombre_acteurs_connus', 'acteurs_connus'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
# X = df.drop(['boxoffice','date','acteurs','awards','box_office_total',
#        'description','nominations','note_presse','note_spectateurs', 'nombre_article','acteurs_connus','nationalités','langue_d_origine','genres','titre'], axis=1)

# Les colonnes à guarger:'titre','durée', 'réalisateur', 'distributeur','nationalités', 'langue_d_origine', 'type_film', 'annee_production','nombre_article','description', 
# 'genres','nombre_acteurs_connus',

X = df.drop(['boxoffice','date','acteurs','awards','box_office_total',
        'description','nominations','note_presse','note_spectateurs', 'nombre_article','acteurs_connus','titre','genre'], axis=1)
y = df['boxoffice']
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, shuffle=True, random_state=42)

# %%
X.head(100)
# Out:
#     durée          réalisateur  \
# 0    92.0        Aaron Horvath
# 1    90.0    Isabelle Mergault
# 2    73.0         Arnaud Viard
# 3    99.0    Matthias Luthardt
# 4   123.0  Christian Schwochow
# ..    ...                  ...
# 95  120.0    Mark Dornford-May
# 96   59.0     Cecil B. DeMille
# 97  124.0      Christian-Jaque
# 98  109.0           David Ayer
# 99   92.0            Adele Lim
#
#                                       distributeur    nationalités  \
# 0          Universal Pictures International France          U.S.A.
# 1                                        Zinc Film          France
# 2                     Moonlight Films Distribution          France
# 3                            Pyramide Distribution          France
# 4   Happiness Distribution / Pyramide Distribution       Allemagne
# ..                                             ...             ...
# 95                                 ID Distribution  Afrique du Sud
# 96                                         inconnu          U.S.A.
# 97                                         inconnu          France
# 98                         Metropolitan FilmExport          U.S.A.
# 99                         Metropolitan FilmExport          U.S.A.
#
#      langue_d_origine     type_film  annee_production  nombre_acteurs_connus
# 0             Anglais  Long-métrage              2023                      1
# 1            Français  Long-métrage              2023                      2
# 2            Français  Long-métrage              2023                      0
# 3            Français  Long-métrage              2023                      0
# 4            Allemand  Long-métrage              2016                      0
# ..                ...           ...               ...                    ...
# 95  Dialecte africain  Long-métrage              2004                      0
# 96               Muet  Long-métrage              1915                      0
# 97                NaN  Long-métrage              1945                      0
# 98            Anglais  Long-métrage              2014                      2
# 99            Anglais  Long-métrage              2023                      0
#
# [100 rows x 8 columns]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3948 entries, 0 to 3947
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   durée                  3948 non-null   float64
#  1   réalisateur            3948 non-null   object
#  2   distributeur           3948 non-null   object
#  3   nationalités           3948 non-null   object
#  4   langue_d_origine       3931 non-null   object
#  5   type_film              3948 non-null   object
#  6   annee_production       3948 non-null   int64
#  7   nombre_acteurs_connus  3948 non-null   int64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 246.9+ KB

# %%
X['distributeur'].nunique()
# Out:
# 332

# %%
# Import des bibliothèques
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression

# Définir vos caractéristiques catégorielles et numériques
# categorical_features = ['titre','réalisateur','distributeur','nationalités','langue_d_origine','type_film','genres']
categorical_features = ['réalisateur','distributeur','nationalités','langue_d_origine','type_film']

numerical_features = ['durée', 'annee_production','nombre_acteurs_connus']

# Créer le transformateur pour les caractéristiques catégorielles
categorical_transformer = OneHotEncoder(sparse=True)   #, handle_unknown='ignore')


# Créer le transformateur pour les caractéristiques numériques
numerical_transformer = StandardScaler()

# Créer le preprocessor en utilisant le ColumnTransformer pour gérer les deux types de caractéristiques
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', categorical_transformer, categorical_features),
        ('num', numerical_transformer, numerical_features)
    ],
    remainder="passthrough" 
)

# Créer le modèle de régression linéaire
lin_reg = LinearRegression()

# Créer le pipeline en spécifiant les étapes dans l'ordre
pipe = Pipeline([
     ('preprocessor', preprocessor),
     ('lin_reg', lin_reg)
])

pipe
# Out:
#   Cell In[517], line 21
#     preprocessor = ColumnTransformer(
#                                     ^
# SyntaxError: '(' was never closed

# %%
# Ajuster (fit) le pipeline avec les données d'entraînement
pipe.fit(X_train, y_train)
# Out:
# /home/apprenant/miniconda3/envs/myenv/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=True),
#                                                   ['réalisateur',
#                                                    'distributeur',
#                                                    'nationalités',
#                                                    'langue_d_origine',
#                                                    'type_film']),
#                                                  ('num', StandardScaler(),
#                                                   ['durée', 'annee_production',
#                                                    'nombre_acteurs_connus'])])),
#                 ('lin_reg', LinearRegression())])

# %%
# Maintenant que le pipeline est ajusté, vous pouvez faire des prédictions
y_pred_train = pipe.predict(X_train)
y_pred_test = pipe.predict(X_test)
y_pred_test
# Out:
# array([-1.67794219e+06,  4.45465740e+06,  4.15401411e+05, -2.63050464e+06,
#         2.35590019e+04,  1.83363898e+06,  7.94388567e+05,  3.97177496e+05,
#        -1.78878777e+05, -5.89879465e+05,  6.74600678e+06, -9.46109038e+05,
#         5.37548131e+06, -7.25815270e+05,  1.07920762e+07,  4.97607886e+05,
#        -1.87686443e+05,  9.55624962e+05, -8.40271567e+05, -7.64791771e+05,
#        -2.96184729e+06,  3.32490042e+05,  2.47664059e+06, -3.17030131e+06,
#         1.14363207e+06,  4.21783846e+05,  4.08295249e+05,  4.28620048e+06,
#         1.20990564e+06,  4.51155730e+06, -1.35609241e+06,  9.48314968e+05,
#         5.25352454e+05, -5.46866060e+05, -2.05909279e+06, -4.39420911e+05,
#         1.90058331e+03, -7.04497512e+04, -4.90435576e+05,  2.23457710e+06,
#         1.45849847e+05,  2.08851040e+06,  4.01272462e+06,  1.22975689e+06,
#         5.28813037e+05, -1.22502119e+06,  1.88634439e+06,  2.23130033e+05,
#         1.42114450e+05,  1.00670767e+06,  1.03445790e+06,  1.14479790e+06,
#         2.04561329e+06,  4.38506087e+05,  9.26803974e+05,  4.33165519e+05,
#         2.53098475e+06, -3.64947016e+05,  1.76828804e+02,  4.18427630e+04,
#         1.11223866e+06,  4.21107809e+06,  1.76165046e+06,  2.15172254e+05,
#         5.76469660e+05, -4.49724183e+05,  6.90613684e+04, -2.93906472e+04,
#        -7.79002856e+04,  4.84795364e+05,  2.29363922e+06,  9.11188001e+05,
#        -3.07268576e+06,  1.58101487e+06,  8.28585865e+06, -1.68985495e+06,
#        -5.96484515e+05,  2.67824052e+05, -4.50756932e+04, -7.45685501e+04,
#        -1.07387195e+06, -6.17704632e+03, -4.12542851e+06, -1.65746204e+06,
#         1.01307960e+06,  2.88645313e+05, -3.97332445e+04,  3.95977579e+03,
#         6.74025614e+06,  9.49469755e+06,  9.56296809e+05,  2.40847177e+06,
#         4.43061387e+06,  1.19223572e+06,  5.09392106e+06,  1.25604113e+05,
#        -7.75612947e+05,  1.05867801e+05,  5.82466201e+06,  3.03178795e+06,
#        -2.14122358e+06,  3.70685650e+05,  1.23043698e+06,  2.96275591e+05,
#         6.02613706e+05,  7.42430690e+05,  5.82875855e+05,  2.50068560e+05,
#         3.00329034e+05,  2.93830904e+06, -3.20342455e+05, -3.17524719e+05,
#        -1.38762551e+06,  3.98436125e+06,  4.97751595e+06,  9.30855173e+05,
#         2.88341677e+06, -2.11778589e+05, -2.89360028e+05, -2.53324638e+06,
#         6.93173392e+05, -2.11451982e+06,  1.50236631e+06,  1.85669283e+06,
#         1.77094569e+06,  3.23781547e+05,  2.15222945e+06, -4.17148330e+04,
#        -1.47734932e+05,  1.20986990e+06,  6.00096157e+05, -3.32971540e+03,
#        -9.13458977e+04, -1.61651107e+06,  9.94411492e+04,  4.89279355e+05,
#         2.28415187e+05,  6.15885769e+04,  4.90431793e+04, -2.08710102e+06,
#         2.19712351e+06,  8.95872258e+05, -6.53781158e+05, -9.93964606e+05,
#         1.69391440e+06, -4.87659695e+05,  2.27043066e+06, -4.26344649e+05,
#         4.12771268e+06,  1.56377481e+06,  1.39707419e+06, -7.51802620e+05,
#         6.84297122e+05, -9.75572581e+04,  4.90210101e+06,  2.67001943e+05,
#         7.84628247e+05,  6.60157665e+05, -1.01109490e+06,  2.67946951e+06,
#         9.32097868e+03, -7.90223999e+05,  6.95141224e+05, -1.91236573e+03,
#         1.03672935e+05,  5.00264020e+05,  2.60167458e+05,  7.24247729e+05,
#         9.55115363e+05, -1.79484278e+06, -6.37092067e+05,  1.58915147e+06,
#         3.44322020e+05, -9.63497705e+05,  1.65286472e+06,  7.83843861e+05,
#         5.07232259e+06,  6.73002814e+06, -1.19530727e+05,  1.15130372e+06,
#         3.49263424e+03,  1.85827017e+07,  5.63790613e+05, -4.45535676e+05,
#         3.15200014e+06,  5.24736410e+05,  2.27655081e+06,  3.41067728e+05,
#         3.47292411e+05,  8.30140957e+05, -1.73325939e+06, -7.05894112e+05,
#         6.99759136e+05,  8.21677651e+05,  5.84288316e+05,  3.18719529e+05,
#        -6.41035206e+05, -1.64607456e+05])

# %%
print("######## Mean Squared Error (MSE) : ")
print("TRAIN :", mean_squared_error(y_train, y_pred_train))
print("TEST :", mean_squared_error(y_test, y_pred_test))
# Out:
# ######## Mean Squared Error (MSE) :
# TRAIN : 1495357098183.4656
# TEST : 14440154636755.398

# %%
rmse_train = np.sqrt(mean_squared_error(y_train, y_pred_train))
rmse_test = np.sqrt(mean_squared_error(y_test, y_pred_test))
print("######## Root Mean Squared Error (RMSE) : ")
print("TRAIN :", rmse_train)
print("TEST :", rmse_test)
# Out:
# ######## Root Mean Squared Error (RMSE) :
# TRAIN : 1222847.945651243
# TEST : 3800020.3468870264

# %%
print("######## Mean Absolute Error (MAE) : ")
print("TRAIN :", mean_absolute_error(y_train, y_pred_train))
print("TEST :", mean_absolute_error(y_test, y_pred_test))
# Out:
# ######## Mean Absolute Error (MAE) :
# TRAIN : 357752.0110604492
# TEST : 1752244.215356313

# %%
print("######## R-squared (R2) : ")
print("TRAIN :", r2_score(y_train, y_pred_train))
print("TEST :", r2_score(y_test, y_pred_test))
# Out:
# ######## R-squared (R2) :
# TRAIN : 0.8155457050226623
# TEST : -0.008114849328965335
