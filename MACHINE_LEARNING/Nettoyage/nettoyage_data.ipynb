# %% [markdown]
# # <center><b> <em> Data Preprocessing </em> </b></center>

# %% [markdown]
# ## <font color="green"> | - Import des Biblio et Dataframe</font>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import numpy as np

# %%
# Read the XLSX file
data = pd.read_csv("data/dataset_model_bronze.csv")

# %%
data.head()
# Out:
#                    titre        date  \
# 0   La Maison de la mort  1934-04-06
# 1       La Vie est belle  1947-12-10
# 2             Cendrillon  1950-12-01
# 3           La Passagère  1964-10-28
# 4  La Planète des singes  1968-04-26
#
#                                             genre  duree  \
# 0                               Epouvante-horreur   72.0
# 1    Comédie dramatique_Comédie_Drame_Fantastique  129.0
# 2  Animation_Comédie musicale_Fantastique_Romance   75.0
# 3                                           Drame   62.0
# 4                           Drame_Science fiction  110.0
#
#              realisateur               distributeur  \
# 0            James Whale             Carlotta Films
# 1            Frank Capra         Swashbuckler Films
# 2        Wilfred Jackson  Buena Vista International
# 3           Andrzej Munk             Malavida Films
# 4  Franklin J. Schaffner         Swashbuckler Films
#
#                                             acteurs nationalites  \
# 0     Boris Karloff,Melvyn Douglas,Charles Laughton       U.S.A.
# 1         James Stewart,Donna Reed,Lionel Barrymore       U.S.A.
# 2           Ilene Woods,Eleanor Audley,Verna Felton       U.S.A.
# 3  Anna Ciepielewska,Aleksandra Slaska,Jan Kreczmar      Pologne
# 4         Charlton Heston,Roddy McDowall,Kim Hunter       U.S.A.
#
#   langue_d_origine     type_film  annee_production nombre_article  \
# 0          Anglais  Long-métrage              1932             15
# 1          Anglais  Long-métrage              1946              6
# 2          Anglais  Long-métrage              1950            217
# 3         Polonais  Long-métrage              1961              8
# 4          Anglais  Long-métrage              1968              1
#
#                                          description  film_id_allocine  \
# 0  Alors qu’ils traversent une région isolée du p...             43316
# 1  Le décès de son père oblige un homme à reprend...              5762
# 2  Cendrillon, servante de sa marâtre et de ses d...             38826
# 3  Liza subit un choc, quand, lors d'une croisièr...              2314
# 4  Egaré dans l'espace-temps, un engin spatial am...             12791
#
#                                                image  boxoffice
# 0  https://fr.web.img3.acsta.net/c_310_420/pictur...        911
# 1  https://fr.web.img6.acsta.net/c_310_420/pictur...     734571
# 2  https://fr.web.img5.acsta.net/c_310_420/medias...      38457
# 3  https://fr.web.img6.acsta.net/c_310_420/pictur...       1420
# 4  https://fr.web.img6.acsta.net/c_310_420/pictur...     175773

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7114 entries, 0 to 7113
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   titre             7114 non-null   object
#  1   date              7114 non-null   object
#  2   genre             7114 non-null   object
#  3   duree             7098 non-null   float64
#  4   realisateur       7114 non-null   object
#  5   distributeur      7114 non-null   object
#  6   acteurs           7020 non-null   object
#  7   nationalites      7114 non-null   object
#  8   langue_d_origine  7114 non-null   object
#  9   type_film         7114 non-null   object
#  10  annee_production  7114 non-null   int64
#  11  nombre_article    7114 non-null   object
#  12  description       6397 non-null   object
#  13  film_id_allocine  7114 non-null   int64
#  14  image             7114 non-null   object
#  15  boxoffice         7114 non-null   int64
# dtypes: float64(1), int64(3), object(12)
# memory usage: 889.4+ KB

# %%
data.shape
# Out:
# (7114, 16)

# %% [markdown]
# ## <font color="green"> || - Missing Data </font>

# %%
# Create a figure and axes for the plot
fig, ax = plt.subplots()
sns.heatmap(data.isnull(), ax=ax, yticklabels=False, cbar=False, cmap="Blues")
ax.set_title("Heatmap of Missing Values")
plt.show()

# %%
data.isnull().sum()
# Out:
# titre                 0
# date                  0
# genre                 0
# duree                16
# realisateur           0
# distributeur          0
# acteurs              94
# nationalites          0
# langue_d_origine      0
# type_film             0
# annee_production      0
# nombre_article        0
# description         717
# film_id_allocine      0
# image                 0
# boxoffice             0
# dtype: int64

# %%
# Afficher les lignes contenant des NaN dans le DataFrame
lignes_nan = data[data['acteurs'].isnull()]
lignes_nan.head()
# Out:
#                          titre        date      genre  duree  \
# 1392   Laban, le petit fantôme  2008-12-03  Animation   52.0
# 1435   Des idiots et des anges  2009-01-14  Animation   76.0
# 2053           En promenade...  2010-09-22  Animation   36.0
# 2080  Ma petite planète chérie  2010-10-20  Animation   44.0
# 2095    Les Contes de la ferme  2010-11-10  Animation   38.0
#
#               realisateur        distributeur acteurs        nationalites  \
# 1392        Lasse Persson  Les Films du Préau     NaN               Suède
# 1435        Bill Plympton     Ed Distribution     NaN              U.S.A.
# 2053        Siri Melchior  Les Films du Préau     NaN            Danemark
# 2080  Jacques-Rémy Girerd            Folimage     NaN              France
# 2095      Hermina Tyrlova                KMBO     NaN  République tchèque
#
#      langue_d_origine        type_film  annee_production nombre_article  \
# 1392          Suédois     Long-métrage              2006              3
# 1435          Anglais     Long-métrage              2009             27
# 2053                -  Film à sketches              2010           None
# 2080         Français     Long-métrage              2010              5
# 2095                -  Film à sketches              2010           None
#
#                                             description  film_id_allocine  \
# 1392  Laban vit au château Froussard avec Papa fantô...            139254
# 1435  Angel est un homme égoïste et sans principes q...            137382
# 2053  Partez à la rencontre d’un petit homme qui déc...            183976
# 2080  Neuf histoires qui abordent l’écologie de mani...             57186
# 2095  Un programme de cinq courts métrages d'animati...            185089
#
#                                                   image  boxoffice
# 1392  https://fr.web.img6.acsta.net/c_310_420/medias...        462
# 1435  https://fr.web.img6.acsta.net/c_310_420/medias...       6452
# 2053  https://fr.web.img4.acsta.net/c_310_420/medias...       5294
# 2080  https://fr.web.img3.acsta.net/c_310_420/medias...       8784
# 2095  https://fr.web.img4.acsta.net/c_310_420/medias...       2745

# %%
# Supprimer les lignes contenant des NaN dans la colonne 'acteurs'
data = data.dropna(subset=['acteurs'])

# %%
# Supprimer les lignes contenant des NaN dans la colonne 'acteurs'
data = data.dropna(subset=['realisateur'])

# %%
data = data.dropna(subset=['langue_d_origine'])

# %%
data.shape
# Out:
# (7020, 16)

# %%
data.columns
# Out:
# Index(['titre', 'date', 'genre', 'duree', 'realisateur', 'distributeur',
#        'acteurs', 'nationalites', 'langue_d_origine', 'type_film',
#        'annee_production', 'nombre_article', 'description', 'film_id_allocine',
#        'image', 'boxoffice'],
#       dtype='object')

# %%
# Afficher les lignes contenant des NaN dans le DataFrame
lignes_nan = data[data['duree'].isnull()]
lignes_nan.head()
# Out:
#                             titre        date  \
# 583               Si seulement...  2004-11-24
# 1525  Le Monde merveilleux d'Impy  2009-04-08
# 2457             Chiens de paille  2011-11-09
# 2922          Beautiful creatures  2013-01-16
# 3120                   Raanjhanaa  2013-06-21
#
#                                        genre  duree      realisateur  \
# 583   Comédie dramatique_Fantastique_Romance    NaN       Gil Junger
# 1525                       Animation_Famille    NaN  Reinhard Klooss
# 2457                                Thriller    NaN        Rod Lurie
# 2922                  Comédie_Drame_Thriller    NaN      Bill Eagles
# 3120                                 Romance    NaN       Aanand Rai
#
#      distributeur                                            acteurs  \
# 583           SND  Jennifer Love Hewitt,Paul Nicholls,Lucy Davenport
# 1525  Océan Films           Hannes Maurer,Wigald Boning,Anke Engelke
# 2457            -    James Marsden,Kate Bosworth,Alexander Skarsgård
# 2922            -                       Rachel Weisz,Susan Lynch (I)
# 3120  Aanna Films                  V Dhanush,Sonam Kapoor,Abhay Deol
#
#          nationalites langue_d_origine     type_film  annee_production  \
# 583            U.S.A.          Anglais  Long-métrage              2004
# 1525        Allemagne         Allemand  Long-métrage              2008
# 2457           U.S.A.          Anglais  Long-métrage              2011
# 2922  Grande-Bretagne                -  Long-métrage              2000
# 3120             Inde            Hindi  Long-métrage              2013
#
#      nombre_article                                        description  \
# 583              13  Et si le destin lui offrait une seconde chance...
# 1525              8  Pour son anniversaire, Impy le dinosaure reçoi...
# 2457             66  Un Anglais et sa femme quittent le pays pour a...
# 2922              3                                               None
# 3120              3           L'histoire d'amour entre Kundan et Zoya.
#
#       film_id_allocine                                              image  \
# 583              47219  https://fr.web.img4.acsta.net/c_310_420/medias...
# 1525            134513  https://fr.web.img4.acsta.net/c_310_420/medias...
# 2457            127658  https://fr.web.img5.acsta.net/c_310_420/medias...
# 2922             29343  https://fr.web.img3.acsta.net/c_310_420/medias...
# 3120            221396  https://fr.web.img3.acsta.net/c_310_420/pictur...
#
#       boxoffice
# 583       30159
# 1525      32010
# 2457    5000000
# 2922    3410000
# 3120     414211

# %%
# Imputer les valeurs manquantes dans la colonne 'colonne1' par la moyenne
moyenne_colonne = data['duree'].mean()
data['duree'] = data['duree'].fillna(moyenne_colonne)

# %%
data.isnull().sum()
# Out:
# titre                 0
# date                  0
# genre                 0
# duree                 0
# realisateur           0
# distributeur          0
# acteurs               0
# nationalites          0
# langue_d_origine      0
# type_film             0
# annee_production      0
# nombre_article        0
# description         706
# film_id_allocine      0
# image                 0
# boxoffice             0
# dtype: int64

# %% [markdown]
# ## <font color="green"> ||| - Duplicated Data </font>

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data = data.drop_duplicates()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7020 entries, 0 to 7113
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   titre             7020 non-null   object
#  1   date              7020 non-null   object
#  2   genre             7020 non-null   object
#  3   duree             7020 non-null   float64
#  4   realisateur       7020 non-null   object
#  5   distributeur      7020 non-null   object
#  6   acteurs           7020 non-null   object
#  7   nationalites      7020 non-null   object
#  8   langue_d_origine  7020 non-null   object
#  9   type_film         7020 non-null   object
#  10  annee_production  7020 non-null   int64
#  11  nombre_article    7020 non-null   object
#  12  description       6314 non-null   object
#  13  film_id_allocine  7020 non-null   int64
#  14  image             7020 non-null   object
#  15  boxoffice         7020 non-null   int64
# dtypes: float64(1), int64(3), object(12)
# memory usage: 932.3+ KB

# %%
data.isnull().sum()
# Out:
# titre                 0
# date                  0
# genre                 0
# duree                 0
# realisateur           0
# distributeur          0
# acteurs               0
# nationalites          0
# langue_d_origine      0
# type_film             0
# annee_production      0
# nombre_article        0
# description         706
# film_id_allocine      0
# image                 0
# boxoffice             0
# dtype: int64

# %% [markdown]
# ## <font color="green"> IV - Nettoyage Données Quantitatives </font>

# %%
def convert_data_types(df):
    # Convertir la colonne 'date' en type datetime
    df['date'] = pd.to_datetime(df['date'], errors='coerce')

#     # Convertir la colonne 'durée' en type float
#     df['durée'] = pd.to_numeric(df['durée'], errors='coerce')
    df['duree'] = df['duree'].astype(int)


#     # Convertir la colonne 'annee_production' en type int
#     df['annee_production'] = df['annee_production'].astype(int)

#     # Convertir les colonnes 'note_presse' et 'note_spectateurs' en type float
#     df['note_presse'] = pd.to_numeric(df['note_presse'].str.replace(',', '.'), errors='coerce')
#     df['note_spectateurs'] = pd.to_numeric(df['note_spectateurs'].str.replace(',', '.'), errors='coerce')

#     # Convertir la colonne 'nombre_article' en type int en gardant seulement le nombre
#     df['nombre_article'] = df['nombre_article'].str.extract('(\d+)').astype(float)
    # Remplacer les NaN par 0 dans la colonne 'nombre_article'
    df['nombre_article'].fillna(0, inplace=True)
    df['nombre_article'] = df['nombre_article'].astype(int)

#     # Enlever le texte dans la colonne 'box_office_total' et convertir en type int
#     df['box_office_total'] = df['box_office_total'].str.replace(' ', '').str.replace('entrées', '')

#     # Convert the 'box_office_total' column to type int using pd.to_numeric with errors='coerce'
#     df['box_office_total'] = pd.to_numeric(df['box_office_total'], errors='coerce').astype('Int64')
    
#     # Convertir la colonne 'boxoffice' en type int
#     df['boxoffice'] = df['boxoffice'].str.replace(' ', '').astype(int)

    return df

# %%
data_propre = convert_data_types(data)
data_propre
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 data_propre = convert_data_types(data)
#       2 data_propre
#
# Cell In[21], line 21, in convert_data_types(df)
#      10 #     # Convertir la colonne 'annee_production' en type int
#      11 #     df['annee_production'] = df['annee_production'].astype(int)
#      12
#    (...)
#      18 #     df['nombre_article'] = df['nombre_article'].str.extract('(\d+)').astype(float)
#      19     # Remplacer les NaN par 0 dans la colonne 'nombre_article'
#      20     df['nombre_article'].fillna(0, inplace=True)
# ---> 21     df['nombre_article'] = df['nombre_article'].astype(int)
#      23 #     # Enlever le texte dans la colonne 'box_office_total' et convertir en type int
#      24 #     df['box_office_total'] = df['box_office_total'].str.replace(' ', '').str.replace('entrées', '')
#      25
#    (...)
#      29 #     # Convertir la colonne 'boxoffice' en type int
#      30 #     df['boxoffice'] = df['boxoffice'].str.replace(' ', '').astype(int)
#      32     return df
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
#     447 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/managers.py:352, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353 except (TypeError, NotImplementedError):
#     354     if not ignore_failures:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/blocks.py:526, in Block.astype(self, dtype, copy, errors)
#     508 """
#     509 Coerce to the new dtype.
#     510
#    (...)
#     522 Block
#     523 """
#     524 values = self.values
# --> 526 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     528 new_values = maybe_coerce_values(new_values)
#     529 newb = self.make_block(new_values)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:299, in astype_array_safe(values, dtype, copy, errors)
#     296     return values.copy()
#     298 try:
# --> 299     new_values = astype_array(values, dtype, copy=copy)
#     300 except (ValueError, TypeError):
#     301     # e.g. astype_nansafe can fail on object-dtype of strings
#     302     #  trying to convert to float
#     303     if errors == "ignore":
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:230, in astype_array(values, dtype, copy)
#     227     values = values.astype(dtype, copy=copy)
#     229 else:
# --> 230     values = astype_nansafe(values, dtype, copy=copy)
#     232 # in pandas we don't store numpy str dtypes, so convert to object
#     233 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:170, in astype_nansafe(arr, dtype, copy, skipna)
#     166     raise ValueError(msg)
#     168 if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     169     # Explicit copy, or required since NumPy can't view from / to object.
# --> 170     return arr.astype(dtype, copy=True)
#     172 return arr.astype(dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: 'None'

# %%
data_propre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7019 entries, 0 to 7113
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   titre             7019 non-null   object
#  1   date              7019 non-null   datetime64[ns]
#  2   genre             7019 non-null   object
#  3   duree             7019 non-null   int64
#  4   realisateur       7019 non-null   object
#  5   distributeur      7019 non-null   object
#  6   acteurs           7019 non-null   object
#  7   nationalites      7015 non-null   object
#  8   langue_d_origine  7019 non-null   object
#  9   type_film         7019 non-null   object
#  10  annee_production  7019 non-null   int64
#  11  nombre_article    7019 non-null   int64
#  12  description       6289 non-null   object
#  13  film_id_allocine  7019 non-null   int64
#  14  image             7019 non-null   object
#  15  boxoffice         7019 non-null   int64
# dtypes: datetime64[ns](1), int64(5), object(10)
# memory usage: 932.2+ KB

# %%
# # Imputer les valeurs manquantes dans la colonne 'colonne1' par la moyenne
# moyenne_colonne = data_propre['note_presse'].mean()
# data_propre['note_presse'] = data_propre['note_presse'].fillna(moyenne_colonne)

# %%
# # Imputer les valeurs manquantes dans la colonne 'colonne1' par la moyenne
# moyenne_colonne = data_propre['note_spectateurs'].mean()
# data_propre['note_spectateurs'] = data_propre['note_spectateurs'].fillna(moyenne_colonne)

# %%
data_propre.head()
# Out:
#                    titre       date  \
# 0   La Maison de la mort 1934-04-06
# 1       La Vie est belle 1947-12-10
# 2             Cendrillon 1950-12-01
# 3           La Passagère 1964-10-28
# 4  La Planète des singes 1968-04-26
#
#                                             genre  duree  \
# 0                               Epouvante-horreur     72
# 1    Comédie dramatique_Comédie_Drame_Fantastique    129
# 2  Animation_Comédie musicale_Fantastique_Romance     75
# 3                                           Drame     62
# 4                           Drame_Science fiction    110
#
#              realisateur               distributeur  \
# 0            James Whale             Carlotta Films
# 1            Frank Capra         Swashbuckler Films
# 2        Wilfred Jackson  Buena Vista International
# 3           Andrzej Munk             Malavida Films
# 4  Franklin J. Schaffner         Swashbuckler Films
#
#                                             acteurs nationalites  \
# 0     Boris Karloff,Melvyn Douglas,Charles Laughton       U.S.A.
# 1         James Stewart,Donna Reed,Lionel Barrymore       U.S.A.
# 2           Ilene Woods,Eleanor Audley,Verna Felton       U.S.A.
# 3  Anna Ciepielewska,Aleksandra Slaska,Jan Kreczmar      Pologne
# 4         Charlton Heston,Roddy McDowall,Kim Hunter       U.S.A.
#
#   langue_d_origine     type_film  annee_production  nombre_article  \
# 0          Anglais  Long-métrage              1932              15
# 1          Anglais  Long-métrage              1946               6
# 2          Anglais  Long-métrage              1950             217
# 3         Polonais  Long-métrage              1961               8
# 4          Anglais  Long-métrage              1968               1
#
#                                          description  film_id_allocine  \
# 0  Alors qu’ils traversent une région isolée du p...             43316
# 1  Le décès de son père oblige un homme à reprend...              5762
# 2  Cendrillon, servante de sa marâtre et de ses d...             38826
# 3  Liza subit un choc, quand, lors d'une croisièr...              2314
# 4  Egaré dans l'espace-temps, un engin spatial am...             12791
#
#                                                image  boxoffice
# 0  https://fr.web.img3.acsta.net/c_310_420/pictur...        911
# 1  https://fr.web.img6.acsta.net/c_310_420/pictur...     734571
# 2  https://fr.web.img5.acsta.net/c_310_420/medias...      38457
# 3  https://fr.web.img6.acsta.net/c_310_420/pictur...       1420
# 4  https://fr.web.img6.acsta.net/c_310_420/pictur...     175773

# %%
print(data_propre['type_film'].unique())
# Out:
# ['Long-métrage' 'Télefilm' 'Film à sketches' 'Sérials']

# %%
# print(data_propre['box_office_total'].unique())

# %% [markdown]
# ## <font color="green"> V - Nettoyage Données Qualitatives </font>

# %%
# Count NaN values in each column
nan_counts = data_propre.isna().sum()
nan_counts
# Out:
# titre                 0
# date                  0
# genre                 0
# duree                 0
# realisateur           0
# distributeur          0
# acteurs               0
# nationalites          4
# langue_d_origine      0
# type_film             0
# annee_production      0
# nombre_article        0
# description         730
# film_id_allocine      0
# image                 0
# boxoffice             0
# dtype: int64

# %%
print(data_propre['genre'])
# Out:
# 0                                    Epouvante-horreur
# 1         Comédie dramatique_Comédie_Drame_Fantastique
# 2       Animation_Comédie musicale_Fantastique_Romance
# 3                                                Drame
# 4                                Drame_Science fiction
#                              ...
# 7109                                   Comédie_Famille
# 7110                        Animation_Aventure_Famille
# 7111                  Comédie dramatique_Comédie_Drame
# 7112                                            Action
# 7113                              Biopic_Drame_Musical
# Name: genre, Length: 7019, dtype: object

# %%
print(data_propre['genre'].unique())
# Out:
# ['Epouvante-horreur' 'Comédie dramatique_Comédie_Drame_Fantastique'
#  'Animation_Comédie musicale_Fantastique_Romance' 'Drame'
#  'Drame_Science fiction' 'Biopic_Drame' 'Drame_Guerre' 'Action_Aventure'
#  'Aventure_Famille_Science fiction' 'Aventure_Science fiction'
#  'Policier_Thriller' 'Epouvante-horreur_Thriller' 'Action_Drame_Romance'
#  'Drame_Romance' 'Comédie dramatique'
#  'Animation_Comédie musicale_Famille_Romance' 'Comédie_Fantastique'
#  'Animation_Aventure_Comédie musicale_Famille' 'Action'
#  'Animation_Comédie_Famille' 'Comédie dramatique_Romance'
#  'Action_Aventure_Romance' 'Fantastique_Thriller' 'Comédie_Drame'
#  'Drame_Historique' 'Animation_Aventure_Comédie_Famille'
#  'Animation_Aventure_Drame' 'Action_Espionnage_Thriller'
#  'Action_Aventure_Western' 'Animation_Comédie_Musical'
#  'Drame_Erotique_Thriller' 'Comédie' 'Policier_Romance_Thriller'
#  'Biopic_Comédie dramatique_Historique' 'Comédie_Fantastique_Romance'
#  'Aventure_Fantastique_Science fiction' 'Drame_Thriller' 'Thriller'
#  'Animation_Aventure_Comédie' 'Comédie_Romance' 'Aventure_Drame'
#  'Comédie musicale_Comédie' 'Aventure_Epouvante-horreur_Historique'
#  'Drame_Erotique' 'Drame_Policier_Thriller' 'Drame_Guerre_Thriller'
#  'Comédie dramatique_Fantastique_Sport event' 'Action_Comédie'
#  'Action_Drame_Thriller'
#  'Animation_Aventure_Comédie_Drame_Famille_Fantastique_Science fiction'
#  'Comédie_Science fiction' 'Drame_Epouvante-horreur_Thriller'
#  'Aventure_Fantastique' 'Drame_Policier' 'Espionnage'
#  'Drame_Romance_Thriller' 'Action_Guerre_Romance' 'Comédie_Policier'
#  'Action_Thriller' 'Action_Aventure_Comédie' 'Drame_Musical_Romance'
#  'Action_Policier_Thriller' 'Action_Arts Martiaux_Thriller'
#  'Action_Aventure_Science fiction' 'Action_Drame' 'Science fiction'
#  'Action_Comédie_Policier' 'Fantastique_Policier' 'Action_Policier'
#  'Comédie musicale_Romance' 'Comédie dramatique_Judiciaire_Romance'
#  'Drame_Judiciaire_Romance' 'Aventure_Drame_Science fiction'
#  'Comédie_Famille_Romance' 'Drame_Musical' 'Drame_Fantastique_Thriller'
#  'Epouvante-horreur_Science fiction' 'Animation_Aventure_Famille'
#  'Aventure_Famille_Fantastique' 'Animation'
#  'Drame_Epouvante-horreur_Fantastique' 'Comédie musicale_Drame_Famille'
#  'Epouvante-horreur_Fantastique' 'Comédie_Judiciaire_Thriller'
#  'Action_Drame_Guerre' 'Action_Drame_Policier' 'Action_Science fiction'
#  'Aventure_Drame_Historique' 'Romance_Thriller' 'Comédie_Musical_Romance'
#  'Action_Epouvante-horreur_Fantastique_Science fiction_Thriller'
#  'Comédie_Drame_Romance' 'Animation_Aventure_Fantastique'
#  'Action_Guerre_Historique' 'Aventure_Comédie' 'Comédie_Musical'
#  'Policier' 'Epouvante-horreur_Fantastique_Musical' 'Action_Fantastique'
#  'Animation_Comédie' 'Action_Comédie_Policier_Thriller'
#  'Action_Arts Martiaux' 'Aventure_Comédie_Historique'
#  'Arts Martiaux_Comédie' 'Action_Aventure_Thriller'
#  'Biopic_Comédie dramatique' 'Action_Comédie_Epouvante-horreur'
#  'Animation_Aventure' 'Action_Animation_Aventure' 'Action_Aventure_Drame'
#  'Action_Drame_Guerre_Thriller' 'Drame_Guerre_Romance'
#  'Animation_Aventure_Comédie_Famille_Fantastique'
#  'Animation_Aventure_Famille_Fantastique'
#  'Animation_Aventure_Science fiction' 'Biopic_Drame_Historique'
#  'Fantastique' 'Action_Comédie_Science fiction' 'Action_Drame_Historique'
#  'Comédie dramatique_Policier' 'Aventure_Historique'
#  'Comédie_Famille_Fantastique' 'Drame_Romance_Science fiction'
#  'Comédie musicale_Comédie_Drame'
#  'Aventure_Comédie dramatique_Fantastique' 'Action_Comédie_Thriller'
#  'Aventure_Comédie_Romance' 'Epouvante-horreur_Fantastique_Thriller'
#  'Biopic_Comédie_Thriller' 'Drame_Guerre_Historique'
#  'Aventure_Comédie_Espionnage' 'Action_Arts Martiaux_Aventure_Fantastique'
#  'Action_Aventure_Fantastique'
#  'Action_Arts Martiaux_Aventure_Drame_Historique'
#  'Action_Fantastique_Historique' 'Comédie_Famille'
#  'Aventure_Comédie_Drame' 'Comédie_Policier_Romance' 'Erotique_Thriller'
#  'Action_Fantastique_Policier' 'Guerre_Historique' 'Fantastique_Western'
#  'Action_Western' 'Comédie dramatique_Fantastique' 'Drame_Fantastique'
#  'Comédie dramatique_Musical' 'Aventure_Thriller_Western'
#  'Animation_Science fiction' 'Aventure_Comédie_Famille'
#  'Aventure_Drame_Famille' 'Action_Fantastique_Science fiction'
#  'Action_Aventure_Péplum' 'Comédie dramatique_Musical_Romance'
#  'Comédie dramatique_Comédie' 'Action_Science fiction_Thriller'
#  'Drame_Epouvante-horreur_Science fiction' 'Comédie_Fantastique_Western'
#  'Action_Aventure_Espionnage' 'Action_Historique' 'Biopic_Drame_Thriller'
#  'Comédie_Drame_Science fiction' 'Biopic_Drame_Musical'
#  'Comédie dramatique_Comédie musicale' 'Fantastique_Science fiction'
#  'Action_Animation_Aventure_Famille_Fantastique_Thriller'
#  'Action_Arts Martiaux_Drame_Historique'
#  'Comédie dramatique_Fantastique_Romance' 'Comédie_Policier_Thriller'
#  'Aventure' 'Arts Martiaux_Drame' 'Action_Epouvante-horreur_Fantastique'
#  'Science fiction_Thriller' 'Drame_Famille_Fantastique'
#  'Comédie_Drame_Thriller' 'Romance'
#  'Action_Comédie dramatique_Famille_Thriller'
#  'Drame_Fantastique_Science fiction' 'Drame_Sport event'
#  'Comédie dramatique_Thriller' 'Aventure_Comédie_Famille_Fantastique'
#  'Drame_Judiciaire'
#  'Animation_Comédie musicale_Famille_Fantastique_Romance'
#  'Action_Epouvante-horreur_Science fiction' 'Comédie dramatique_Erotique'
#  'Comédie_Famille_Science fiction' 'Aventure_Epouvante-horreur_Thriller'
#  'Animation_Comédie dramatique' 'Action_Comédie_Western'
#  'Drame_Espionnage_Historique_Thriller' 'Biopic_Historique'
#  'Biopic_Drame_Musical_Romance' 'Comédie musicale_Drame_Romance'
#  'Comédie musicale' 'Musical' 'Aventure_Biopic_Comédie dramatique'
#  'Action_Comédie_Espionnage' 'Biopic'
#  'Bollywood_Comédie musicale_Drame_Romance'
#  'Action_Drame_Policier_Thriller' 'Drame_Fantastique_Romance'
#  'Aventure_Comédie dramatique_Famille' 'Western'
#  'Comédie_Drame_Fantastique' 'Biopic_Drame_Sport event'
#  'Drame_Science fiction_Thriller' 'Animation_Famille'
#  'Comédie_Drame_Erotique_Romance' 'Action_Fantastique_Thriller'
#  'Drame_Musical_Policier_Romance' 'Action_Drame_Fantastique'
#  'Action_Policier_Science fiction'
#  'Action_Epouvante-horreur_Fantastique_Thriller'
#  'Drame_Fantastique_Romance_Science fiction' 'Aventure_Drame_Thriller'
#  'Guerre_Romance_Thriller' 'Guerre' 'Fantastique_Romance'
#  'Comédie musicale_Drame_Musical' 'Drame_Historique_Thriller'
#  'Aventure_Drame_Fantastique' 'Bollywood_Drame' 'Biopic_Drame_Policier'
#  'Comédie dramatique_Comédie_Policier_Thriller' 'Animation_Biopic'
#  'Action_Comédie_Famille' 'Biopic_Drame_Espionnage_Historique_Thriller'
#  'Comédie dramatique_Comédie_Drame_Romance' 'Comédie_Epouvante-horreur'
#  'Action_Aventure_Fantastique_Science fiction'
#  'Epouvante-horreur_Science fiction_Thriller' 'Biopic_Drame_Western'
#  'Biopic_Romance' 'Animation_Aventure_Comédie_Famille_Science fiction'
#  'Aventure_Drame_Famille_Fantastique' 'Drame_Espionnage_Thriller'
#  'Action_Aventure_Drame_Fantastique_Science fiction'
#  'Biopic_Comédie dramatique_Musical' 'Aventure_Biopic_Drame'
#  'Drame_Thriller_Western' 'Aventure_Science fiction_Thriller'
#  'Comédie dramatique_Drame' 'Judiciaire_Thriller' 'Drame_Western'
#  'Biopic_Guerre_Historique_Romance' 'Comédie musicale_Comédie_Famille'
#  'Action_Comédie_Fantastique' 'Action_Judiciaire_Thriller'
#  'Action_Animation_Arts Martiaux_Famille' 'Comédie_Erotique_Historique'
#  'Animation_Aventure_Famille_Science fiction' 'Drame_Epouvante-horreur'
#  'Comédie musicale_Comédie_Romance' 'Comédie_Drame_Musical_Romance'
#  'Biopic_Policier' 'Comédie_Espionnage' 'Action_Espionnage'
#  'Aventure_Drame_Guerre_Romance' 'Aventure_Famille' 'Biopic_Guerre'
#  'Comédie dramatique_Comédie_Romance' 'Drame_Judiciaire_Thriller'
#  'Espionnage_Romance' 'Epouvante-horreur_Fantastique_Romance'
#  'Animation_Famille_Fantastique' 'Animation_Drame'
#  'Action_Animation_Science fiction' 'Action_Drame_Science fiction'
#  'Espionnage_Thriller' 'Comédie_Espionnage_Romance_Thriller'
#  'Drame_Epouvante-horreur_Policier' 'Biopic_Historique_Musical'
#  'Action_Aventure_Epouvante-horreur_Thriller'
#  'Action_Biopic_Drame_Thriller' 'Action_Epouvante-horreur_Thriller'
#  'Animation_Bollywood' 'Animation_Aventure_Fantastique_Science fiction'
#  'Epouvante-horreur_Policier' 'Action_Famille_Science fiction'
#  'Animation_Comédie musicale' 'Aventure_Drame_Policier'
#  'Comédie_Epouvante-horreur_Fantastique' 'Animation_Comédie_Fantastique'
#  'Epouvante-horreur_Policier_Thriller' 'Animation_Fantastique'
#  'Aventure_Fantastique_Romance' 'Comédie dramatique_Comédie_Drame'
#  'Aventure_Drame_Romance' 'Bollywood_Comédie' 'Historique'
#  'Comédie dramatique_Historique' 'Action_Aventure_Fantastique_Historique'
#  'Action_Comédie_Romance' 'Drame_Policier_Romance_Thriller'
#  'Comédie musicale_Drame_Historique' 'Drame_Famille'
#  'Comédie musicale_Drame' 'Aventure_Thriller' 'Comédie_Thriller'
#  'Action_Aventure_Historique' 'Animation_Aventure_Comédie_Fantastique'
#  'Action_Aventure_Famille_Fantastique' 'Fantastique_Guerre'
#  'Action_Arts Martiaux_Drame_Famille' 'Comédie dramatique_Drame_Romance'
#  'Drame_Erotique_Romance' 'Policier_Science fiction'
#  'Aventure_Drame_Epouvante-horreur_Thriller' 'Biopic_Drame_Judiciaire'
#  'Action_Animation_Thriller' 'Aventure_Comédie_Fantastique'
#  'Comédie dramatique_Famille' 'Animation_Policier'
#  'Animation_Famille_Science fiction' 'Musical_Policier'
#  'Action_Thriller_Western' 'Comédie_Drame_Musical'
#  'Aventure_Drame_Western' 'Aventure_Biopic_Drame_Thriller'
#  'Aventure_Comédie_Science fiction' 'Aventure_Comédie_Policier'
#  'Romance_Science fiction' 'Comédie_Historique' 'Policier_Romance'
#  'Aventure_Epouvante-horreur_Science fiction'
#  'Action_Comédie_Guerre_Thriller'
#  'Animation_Arts Martiaux_Aventure_Famille'
#  'Comédie dramatique_Comédie_Drame_Guerre' 'Action_Bollywood'
#  'Animation_Musical_Romance' 'Action_Aventure_Science fiction_Western'
#  'Animation_Aventure_Drame_Famille' 'Action_Animation_Aventure_Famille'
#  'Biopic_Comédie_Drame' 'Animation_Drame_Fantastique'
#  'Animation_Biopic_Drame' 'Divers' 'Action_Aventure_Comédie_Famille'
#  'Epouvante-horreur_Romance_Thriller' 'Comédie_Drame_Famille'
#  'Animation_Western' 'Action_Drame_Western' 'Drame_Historique_Romance'
#  'Bollywood_Romance' 'Action_Drame_Policier_Romance'
#  'Action_Animation_Comédie' 'Comédie_Epouvante-horreur_Romance'
#  'Action_Arts Martiaux_Drame' 'Romance_Science fiction_Thriller'
#  'Fantastique_Policier_Thriller' 'Drame_Expérimental'
#  'Action_Comédie_Sport event' 'Animation_Comédie_Famille_Fantastique'
#  'Animation_Comédie dramatique_Romance' 'Action_Guerre'
#  'Comédie_Judiciaire_Policier' 'Animation_Drame_Famille'
#  'Drame_Policier_Romance'
#  'Animation_Aventure_Comédie musicale_Fantastique'
#  'Aventure_Comédie dramatique' 'Animation_Biopic_Drame_Historique'
#  'Aventure_Guerre_Historique' 'Action_Arts Martiaux_Fantastique'
#  'Aventure_Fantastique_Péplum' 'Animation_Drame_Historique'
#  'Biopic_Musical' 'Animation_Drame_Famille_Fantastique' 'Comédie_Western'
#  'Action_Arts Martiaux_Aventure' 'Biopic_Drame_Romance'
#  'Action_Fantastique_Péplum' 'Biopic_Drame_Historique_Musical_Romance'
#  'Action_Aventure_Biopic' 'Aventure_Comédie musicale_Fantastique'
#  'Drame_Famille_Romance' 'Historique_Science fiction' 'Drame_Péplum'
#  'Animation_Comédie_Romance' 'Comédie musicale_Epouvante-horreur'
#  'Bollywood' 'Drame_Fantastique_Guerre' 'Espionnage_Policier_Thriller'
#  'Drame_Epouvante-horreur_Romance' 'Aventure_Guerre_Science fiction'
#  'Biopic_Policier_Thriller' 'Aventure_Expérimental_Fantastique'
#  'Comédie musicale_Comédie_Policier' 'Aventure_Western'
#  'Bollywood_Thriller' 'Action_Arts Martiaux_Biopic' 'Aventure_Biopic'
#  'Animation_Comédie_Drame' 'Bollywood_Historique'
#  'Animation_Drame_Erotique_Fantastique'
#  'Drame_Epouvante-horreur_Policier_Thriller' 'Biopic_Comédie_Historique'
#  'Musical_Romance' 'Comédie_Drame_Guerre' 'Biopic_Thriller'
#  'Biopic_Drame_Guerre' 'Comédie dramatique_Guerre'
#  'Comédie_Drame_Sport event' 'Drame_Historique_Policier'
#  'Action_Romance_Science fiction' 'Aventure_Fantastique_Historique'
#  'Animation_Comédie musicale_Famille' 'Comédie_Famille_Policier'
#  'Comédie musicale_Fantastique_Romance' 'Biopic_Drame_Policier_Thriller'
#  'Action_Historique_Thriller' 'Aventure_Epouvante-horreur_Fantastique'
#  'Historique_Policier_Thriller'
#  'Animation_Comédie_Drame_Famille_Fantastique' 'Biopic_Comédie'
#  'Action_Animation' 'Comédie_Drame_Policier'
#  'Comédie dramatique_Drame_Fantastique' 'Espionnage_Policier'
#  'Biopic_Epouvante-horreur' 'Action_Animation_Policier'
#  'Comédie_Drame_Policier_Thriller' 'Animation_Drame_Romance'
#  'Famille_Fantastique' 'Animation_Comédie_Drame_Famille'
#  'Drame_Espionnage' 'Action_Animation_Famille'
#  'Comédie_Fantastique_Science fiction' 'Action_Comédie dramatique'
#  'Action_Romance_Thriller' 'Action_Guerre_Thriller'
#  'Drame_Espionnage_Musical_Romance' 'Biopic_Comédie musicale'
#  'Drame_Policier_Science fiction' 'Bollywood_Drame_Historique'
#  'Action_Bollywood_Thriller' 'Bollywood_Comédie_Drame'
#  'Action_Bollywood_Historique' 'Famille_Romance_Science fiction'
#  'Aventure_Epouvante-horreur' 'Comédie dramatique_Comédie_Drame_Policier'
#  'Biopic_Guerre_Historique' 'Action_Arts Martiaux_Biopic_Drame'
#  'Comédie dramatique_Comédie_Drame_Epouvante-horreur'
#  'Action_Epouvante-horreur' 'Action_Animation_Policier_Thriller'
#  'Aventure_Comédie_Musical_Science fiction'
#  'Biopic_Drame_Historique_Thriller'
#  'Action_Comédie musicale_Comédie_Drame_Romance'
#  'Comédie_Epouvante-horreur_Science fiction'
#  'Action_Arts Martiaux_Aventure_Thriller' 'Drame_Fantastique_Historique'
#  'Action_Animation_Fantastique' 'Animation_Fantastique_Romance'
#  'Action_Animation_Drame_Fantastique' 'Famille'
#  'Action_Animation_Comédie_Drame_Policier'
#  'Drame_Epouvante-horreur_Science fiction_Thriller'
#  'Comédie_Drame_Romance_Science fiction'
#  'Action_Animation_Comédie_Famille'
#  'Action_Arts Martiaux_Comédie_Drame_Science fiction'
#  'Action_Aventure_Comédie_Science fiction'
#  'Comédie musicale_Comédie_Science fiction'
#  'Action_Animation_Arts Martiaux_Fantastique'
#  'Animation_Arts Martiaux_Comédie_Famille' 'Bollywood_Drame_Romance'
#  'Animation_Thriller' 'Animation_Drame_Fantastique_Historique_Musical'
#  'Comédie_Epouvante-horreur_Thriller' 'Comédie_Historique_Romance'
#  'Comédie dramatique_Comédie_Drame_Judiciaire_Policier'
#  'Animation_Drame_Science fiction' 'Action_Aventure_Comédie_Fantastique'
#  'Animation_Epouvante-horreur_Expérimental_Fantastique'
#  'Action_Aventure_Drame_Historique' 'Musical_Science fiction'
#  'Biopic_Epouvante-horreur_Fantastique'
#  'Action_Animation_Aventure_Fantastique'
#  'Aventure_Famille_Fantastique_Science fiction']

# %%
print(data_propre['genre'].nunique())
# Out:
# 477

# %%
def nettoyage_qualita(df):
    # Clean 'titre' column by removing leading/trailing whitespaces
    df['titre'] = df['titre'].str.strip()
    # Clean 'genre' column by filling missing values with an appropriate placeholder (e.g., 'Unknown')
    # Clean 'genre' column by replacing missing values with NaN
    #------------------------------------------
    # Clean 'date' column by converting it to datetime and keeping only valid dates
    df['date'] = pd.to_datetime(df['date'], errors='coerce')
    df = df.dropna(subset=['date'])
    # #------------------------------------------
    # # Remove rows where 'type_film' column contains 'Téléfilm' or 'Film à sketches'
    df = df[~df['type_film'].isin(['Téléfilm', 'Film à sketches'])]
    # #------------------------------------------
    # df['genre'] = df['genre'].replace('', np.nan)
    #  # Supprimer les lignes contenant "Comédie" ou "Guerre" dans la colonne 'genre'
    # #  # Appliquer la fonction de regroupement des genres à la colonne 'genre'
    # # df['genre'] = df['genre'].apply(regrouper_genres)
    
    # # Supprimer les lignes contenant des valeurs qui sont pas type 'genre'
    df = df[~df['genre'].str.contains('mai 1960|janvier 1974|""|août 1978|octobre 1972|décembre 1960|2018|nan', na=False)]
    df['genre'] = df['genre'].str.replace('-', '_')
    #------------------------------------------
    #Clean 'realisateur' by removing leading/trailing whitespaces
    df['realisateur'] = df['realisateur'].str.strip()
    #------------------------------------------
    # Clean 'distributeur' column by removing leading/trailing whitespaces
    df['distributeur'] = df['distributeur'].str.strip()
    df['distributeur'] = df['distributeur'].replace('-', 'inconnu')
    #------------------------------------------
    # Clean 'acteurs' column by splitting the names into a list
    df['acteurs'] = df['acteurs'].str.split(',')
    #------------------------------------------
    # Remplacer la liste dans la colonne 'langue_d_origine' par la première valeur de la liste
    df['langue_d_origine'] = df['langue_d_origine'].str.split(',').str[0]
    # Clean 'langue_d_origine' column by removing leading/trailing whitespaces
    df['langue_d_origine'] = df['langue_d_origine'].str.strip()
    df['langue_d_origine'] = df['langue_d_origine'].replace('-', np.nan)
    # df['langue_d_origine'] = df['langue_d_origine'].replace('', 'inconnu')
    #------------------------------------------
    # Clean 'type_film' column by filling missing values with 'Unknown'
    df['type_film'] = df['type_film'].replace('', np.nan)
    #------------------------------------------
    # Clean 'description' column by removing leading/trailing whitespaces
    df['description'] = df['description'].str.strip()
    #------------------------------------------
    # Supprimer les lignes contenant des NaN dans la colonne 'nationalites'
    df = data_propre.dropna(subset=['nationalites'])
    df['genre'] = df['genre'].str.replace('-', '_')

    return df

# %%
data_propre = nettoyage_qualita(data_propre)
# data_propre
# Out:
# /tmp/ipykernel_14551/2943102709.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['genre'] = df['genre'].str.replace('-', '_')

# %%
data_propre.shape
# Out:
# (7015, 16)

# %%
data_propre.isnull().sum()
# Out:
# titre                 0
# date                  0
# genre                 0
# duree                 0
# realisateur           0
# distributeur          0
# acteurs               0
# nationalites          0
# langue_d_origine      0
# type_film             0
# annee_production      0
# nombre_article        0
# description         730
# film_id_allocine      0
# image                 0
# boxoffice             0
# dtype: int64

# %%
data_propre['genre'].unique()
# Out:
# array(['Epouvante_horreur',
#        'Comédie dramatique_Comédie_Drame_Fantastique',
#        'Animation_Comédie musicale_Fantastique_Romance', 'Drame',
#        'Drame_Science fiction', 'Biopic_Drame', 'Drame_Guerre',
#        'Action_Aventure', 'Aventure_Famille_Science fiction',
#        'Aventure_Science fiction', 'Policier_Thriller',
#        'Epouvante_horreur_Thriller', 'Action_Drame_Romance',
#        'Drame_Romance', 'Comédie dramatique',
#        'Animation_Comédie musicale_Famille_Romance',
#        'Comédie_Fantastique',
#        'Animation_Aventure_Comédie musicale_Famille', 'Action',
#        'Animation_Comédie_Famille', 'Comédie dramatique_Romance',
#        'Action_Aventure_Romance', 'Fantastique_Thriller', 'Comédie_Drame',
#        'Drame_Historique', 'Animation_Aventure_Comédie_Famille',
#        'Animation_Aventure_Drame', 'Action_Espionnage_Thriller',
#        'Action_Aventure_Western', 'Animation_Comédie_Musical',
#        'Drame_Erotique_Thriller', 'Comédie', 'Policier_Romance_Thriller',
#        'Biopic_Comédie dramatique_Historique',
#        'Comédie_Fantastique_Romance',
#        'Aventure_Fantastique_Science fiction', 'Drame_Thriller',
#        'Thriller', 'Animation_Aventure_Comédie', 'Comédie_Romance',
#        'Aventure_Drame', 'Comédie musicale_Comédie',
#        'Aventure_Epouvante_horreur_Historique', 'Drame_Erotique',
#        'Drame_Policier_Thriller', 'Drame_Guerre_Thriller',
#        'Comédie dramatique_Fantastique_Sport event', 'Action_Comédie',
#        'Action_Drame_Thriller',
#        'Animation_Aventure_Comédie_Drame_Famille_Fantastique_Science fiction',
#        'Comédie_Science fiction', 'Drame_Epouvante_horreur_Thriller',
#        'Aventure_Fantastique', 'Drame_Policier', 'Espionnage',
#        'Drame_Romance_Thriller', 'Action_Guerre_Romance',
#        'Comédie_Policier', 'Action_Thriller', 'Action_Aventure_Comédie',
#        'Drame_Musical_Romance', 'Action_Policier_Thriller',
#        'Action_Arts Martiaux_Thriller', 'Action_Aventure_Science fiction',
#        'Action_Drame', 'Science fiction', 'Action_Comédie_Policier',
#        'Fantastique_Policier', 'Action_Policier',
#        'Comédie musicale_Romance',
#        'Comédie dramatique_Judiciaire_Romance',
#        'Drame_Judiciaire_Romance', 'Aventure_Drame_Science fiction',
#        'Comédie_Famille_Romance', 'Drame_Musical',
#        'Drame_Fantastique_Thriller', 'Epouvante_horreur_Science fiction',
#        'Animation_Aventure_Famille', 'Aventure_Famille_Fantastique',
#        'Animation', 'Drame_Epouvante_horreur_Fantastique',
#        'Comédie musicale_Drame_Famille', 'Epouvante_horreur_Fantastique',
#        'Comédie_Judiciaire_Thriller', 'Action_Drame_Guerre',
#        'Action_Drame_Policier', 'Action_Science fiction',
#        'Aventure_Drame_Historique', 'Romance_Thriller',
#        'Comédie_Musical_Romance',
#        'Action_Epouvante_horreur_Fantastique_Science fiction_Thriller',
#        'Comédie_Drame_Romance', 'Animation_Aventure_Fantastique',
#        'Action_Guerre_Historique', 'Aventure_Comédie', 'Comédie_Musical',
#        'Policier', 'Epouvante_horreur_Fantastique_Musical',
#        'Action_Fantastique', 'Animation_Comédie',
#        'Action_Comédie_Policier_Thriller', 'Action_Arts Martiaux',
#        'Aventure_Comédie_Historique', 'Arts Martiaux_Comédie',
#        'Action_Aventure_Thriller', 'Biopic_Comédie dramatique',
#        'Action_Comédie_Epouvante_horreur', 'Animation_Aventure',
#        'Action_Animation_Aventure', 'Action_Aventure_Drame',
#        'Action_Drame_Guerre_Thriller', 'Drame_Guerre_Romance',
#        'Animation_Aventure_Comédie_Famille_Fantastique',
#        'Animation_Aventure_Famille_Fantastique',
#        'Animation_Aventure_Science fiction', 'Biopic_Drame_Historique',
#        'Fantastique', 'Action_Comédie_Science fiction',
#        'Action_Drame_Historique', 'Comédie dramatique_Policier',
#        'Aventure_Historique', 'Comédie_Famille_Fantastique',
#        'Drame_Romance_Science fiction', 'Comédie musicale_Comédie_Drame',
#        'Aventure_Comédie dramatique_Fantastique',
#        'Action_Comédie_Thriller', 'Aventure_Comédie_Romance',
#        'Epouvante_horreur_Fantastique_Thriller',
#        'Biopic_Comédie_Thriller', 'Drame_Guerre_Historique',
#        'Aventure_Comédie_Espionnage',
#        'Action_Arts Martiaux_Aventure_Fantastique',
#        'Action_Aventure_Fantastique',
#        'Action_Arts Martiaux_Aventure_Drame_Historique',
#        'Action_Fantastique_Historique', 'Comédie_Famille',
#        'Aventure_Comédie_Drame', 'Comédie_Policier_Romance',
#        'Erotique_Thriller', 'Action_Fantastique_Policier',
#        'Guerre_Historique', 'Fantastique_Western', 'Action_Western',
#        'Comédie dramatique_Fantastique', 'Drame_Fantastique',
#        'Comédie dramatique_Musical', 'Aventure_Thriller_Western',
#        'Animation_Science fiction', 'Aventure_Comédie_Famille',
#        'Aventure_Drame_Famille', 'Action_Fantastique_Science fiction',
#        'Action_Aventure_Péplum', 'Comédie dramatique_Musical_Romance',
#        'Comédie dramatique_Comédie', 'Action_Science fiction_Thriller',
#        'Drame_Epouvante_horreur_Science fiction',
#        'Comédie_Fantastique_Western', 'Action_Aventure_Espionnage',
#        'Action_Historique', 'Biopic_Drame_Thriller',
#        'Comédie_Drame_Science fiction', 'Biopic_Drame_Musical',
#        'Comédie dramatique_Comédie musicale',
#        'Fantastique_Science fiction',
#        'Action_Animation_Aventure_Famille_Fantastique_Thriller',
#        'Action_Arts Martiaux_Drame_Historique',
#        'Comédie dramatique_Fantastique_Romance',
#        'Comédie_Policier_Thriller', 'Aventure', 'Arts Martiaux_Drame',
#        'Action_Epouvante_horreur_Fantastique', 'Science fiction_Thriller',
#        'Drame_Famille_Fantastique', 'Comédie_Drame_Thriller', 'Romance',
#        'Action_Comédie dramatique_Famille_Thriller',
#        'Drame_Fantastique_Science fiction', 'Drame_Sport event',
#        'Comédie dramatique_Thriller',
#        'Aventure_Comédie_Famille_Fantastique', 'Drame_Judiciaire',
#        'Animation_Comédie musicale_Famille_Fantastique_Romance',
#        'Action_Epouvante_horreur_Science fiction',
#        'Comédie dramatique_Erotique', 'Comédie_Famille_Science fiction',
#        'Aventure_Epouvante_horreur_Thriller',
#        'Animation_Comédie dramatique', 'Action_Comédie_Western',
#        'Drame_Espionnage_Historique_Thriller', 'Biopic_Historique',
#        'Biopic_Drame_Musical_Romance', 'Comédie musicale_Drame_Romance',
#        'Comédie musicale', 'Musical',
#        'Aventure_Biopic_Comédie dramatique', 'Action_Comédie_Espionnage',
#        'Biopic', 'Bollywood_Comédie musicale_Drame_Romance',
#        'Action_Drame_Policier_Thriller', 'Drame_Fantastique_Romance',
#        'Aventure_Comédie dramatique_Famille', 'Western',
#        'Comédie_Drame_Fantastique', 'Biopic_Drame_Sport event',
#        'Drame_Science fiction_Thriller', 'Animation_Famille',
#        'Comédie_Drame_Erotique_Romance', 'Action_Fantastique_Thriller',
#        'Drame_Musical_Policier_Romance', 'Action_Drame_Fantastique',
#        'Action_Policier_Science fiction',
#        'Action_Epouvante_horreur_Fantastique_Thriller',
#        'Drame_Fantastique_Romance_Science fiction',
#        'Aventure_Drame_Thriller', 'Guerre_Romance_Thriller', 'Guerre',
#        'Fantastique_Romance', 'Comédie musicale_Drame_Musical',
#        'Drame_Historique_Thriller', 'Aventure_Drame_Fantastique',
#        'Bollywood_Drame', 'Biopic_Drame_Policier',
#        'Comédie dramatique_Comédie_Policier_Thriller', 'Animation_Biopic',
#        'Action_Comédie_Famille',
#        'Biopic_Drame_Espionnage_Historique_Thriller',
#        'Comédie dramatique_Comédie_Drame_Romance',
#        'Comédie_Epouvante_horreur',
#        'Action_Aventure_Fantastique_Science fiction',
#        'Epouvante_horreur_Science fiction_Thriller',
#        'Biopic_Drame_Western', 'Biopic_Romance',
#        'Animation_Aventure_Comédie_Famille_Science fiction',
#        'Aventure_Drame_Famille_Fantastique', 'Drame_Espionnage_Thriller',
#        'Action_Aventure_Drame_Fantastique_Science fiction',
#        'Biopic_Comédie dramatique_Musical', 'Aventure_Biopic_Drame',
#        'Drame_Thriller_Western', 'Aventure_Science fiction_Thriller',
#        'Comédie dramatique_Drame', 'Judiciaire_Thriller', 'Drame_Western',
#        'Biopic_Guerre_Historique_Romance',
#        'Comédie musicale_Comédie_Famille', 'Action_Comédie_Fantastique',
#        'Action_Judiciaire_Thriller',
#        'Action_Animation_Arts Martiaux_Famille',
#        'Comédie_Erotique_Historique',
#        'Animation_Aventure_Famille_Science fiction',
#        'Drame_Epouvante_horreur', 'Comédie musicale_Comédie_Romance',
#        'Comédie_Drame_Musical_Romance', 'Biopic_Policier',
#        'Comédie_Espionnage', 'Action_Espionnage',
#        'Aventure_Drame_Guerre_Romance', 'Aventure_Famille',
#        'Biopic_Guerre', 'Comédie dramatique_Comédie_Romance',
#        'Drame_Judiciaire_Thriller', 'Espionnage_Romance',
#        'Epouvante_horreur_Fantastique_Romance',
#        'Animation_Famille_Fantastique', 'Animation_Drame',
#        'Action_Animation_Science fiction', 'Action_Drame_Science fiction',
#        'Espionnage_Thriller', 'Comédie_Espionnage_Romance_Thriller',
#        'Drame_Epouvante_horreur_Policier', 'Biopic_Historique_Musical',
#        'Action_Aventure_Epouvante_horreur_Thriller',
#        'Action_Biopic_Drame_Thriller',
#        'Action_Epouvante_horreur_Thriller', 'Animation_Bollywood',
#        'Animation_Aventure_Fantastique_Science fiction',
#        'Epouvante_horreur_Policier', 'Action_Famille_Science fiction',
#        'Animation_Comédie musicale', 'Aventure_Drame_Policier',
#        'Comédie_Epouvante_horreur_Fantastique',
#        'Animation_Comédie_Fantastique',
#        'Epouvante_horreur_Policier_Thriller', 'Animation_Fantastique',
#        'Aventure_Fantastique_Romance', 'Comédie dramatique_Comédie_Drame',
#        'Aventure_Drame_Romance', 'Bollywood_Comédie', 'Historique',
#        'Comédie dramatique_Historique',
#        'Action_Aventure_Fantastique_Historique', 'Action_Comédie_Romance',
#        'Drame_Policier_Romance_Thriller',
#        'Comédie musicale_Drame_Historique', 'Drame_Famille',
#        'Comédie musicale_Drame', 'Aventure_Thriller', 'Comédie_Thriller',
#        'Action_Aventure_Historique',
#        'Animation_Aventure_Comédie_Fantastique',
#        'Action_Aventure_Famille_Fantastique', 'Fantastique_Guerre',
#        'Action_Arts Martiaux_Drame_Famille',
#        'Comédie dramatique_Drame_Romance', 'Drame_Erotique_Romance',
#        'Policier_Science fiction',
#        'Aventure_Drame_Epouvante_horreur_Thriller',
#        'Biopic_Drame_Judiciaire', 'Action_Animation_Thriller',
#        'Aventure_Comédie_Fantastique', 'Comédie dramatique_Famille',
#        'Animation_Policier', 'Animation_Famille_Science fiction',
#        'Musical_Policier', 'Action_Thriller_Western',
#        'Comédie_Drame_Musical', 'Aventure_Drame_Western',
#        'Aventure_Biopic_Drame_Thriller',
#        'Aventure_Comédie_Science fiction', 'Aventure_Comédie_Policier',
#        'Romance_Science fiction', 'Comédie_Historique',
#        'Policier_Romance', 'Aventure_Epouvante_horreur_Science fiction',
#        'Action_Comédie_Guerre_Thriller',
#        'Animation_Arts Martiaux_Aventure_Famille',
#        'Comédie dramatique_Comédie_Drame_Guerre', 'Action_Bollywood',
#        'Animation_Musical_Romance',
#        'Action_Aventure_Science fiction_Western',
#        'Animation_Aventure_Drame_Famille',
#        'Action_Animation_Aventure_Famille', 'Biopic_Comédie_Drame',
#        'Animation_Drame_Fantastique', 'Animation_Biopic_Drame', 'Divers',
#        'Action_Aventure_Comédie_Famille',
#        'Epouvante_horreur_Romance_Thriller', 'Comédie_Drame_Famille',
#        'Animation_Western', 'Action_Drame_Western',
#        'Drame_Historique_Romance', 'Bollywood_Romance',
#        'Action_Drame_Policier_Romance', 'Action_Animation_Comédie',
#        'Comédie_Epouvante_horreur_Romance', 'Action_Arts Martiaux_Drame',
#        'Romance_Science fiction_Thriller',
#        'Fantastique_Policier_Thriller', 'Drame_Expérimental',
#        'Action_Comédie_Sport event',
#        'Animation_Comédie_Famille_Fantastique',
#        'Animation_Comédie dramatique_Romance', 'Action_Guerre',
#        'Comédie_Judiciaire_Policier', 'Animation_Drame_Famille',
#        'Drame_Policier_Romance',
#        'Animation_Aventure_Comédie musicale_Fantastique',
#        'Aventure_Comédie dramatique', 'Animation_Biopic_Drame_Historique',
#        'Aventure_Guerre_Historique', 'Action_Arts Martiaux_Fantastique',
#        'Aventure_Fantastique_Péplum', 'Animation_Drame_Historique',
#        'Biopic_Musical', 'Animation_Drame_Famille_Fantastique',
#        'Comédie_Western', 'Action_Arts Martiaux_Aventure',
#        'Biopic_Drame_Romance', 'Action_Fantastique_Péplum',
#        'Biopic_Drame_Historique_Musical_Romance',
#        'Action_Aventure_Biopic', 'Aventure_Comédie musicale_Fantastique',
#        'Drame_Famille_Romance', 'Historique_Science fiction',
#        'Drame_Péplum', 'Animation_Comédie_Romance',
#        'Comédie musicale_Epouvante_horreur', 'Bollywood',
#        'Drame_Fantastique_Guerre', 'Espionnage_Policier_Thriller',
#        'Drame_Epouvante_horreur_Romance',
#        'Aventure_Guerre_Science fiction', 'Biopic_Policier_Thriller',
#        'Aventure_Expérimental_Fantastique',
#        'Comédie musicale_Comédie_Policier', 'Aventure_Western',
#        'Bollywood_Thriller', 'Action_Arts Martiaux_Biopic',
#        'Aventure_Biopic', 'Animation_Comédie_Drame',
#        'Bollywood_Historique', 'Animation_Drame_Erotique_Fantastique',
#        'Drame_Epouvante_horreur_Policier_Thriller',
#        'Biopic_Comédie_Historique', 'Musical_Romance',
#        'Comédie_Drame_Guerre', 'Biopic_Thriller', 'Biopic_Drame_Guerre',
#        'Comédie dramatique_Guerre', 'Comédie_Drame_Sport event',
#        'Drame_Historique_Policier', 'Action_Romance_Science fiction',
#        'Aventure_Fantastique_Historique',
#        'Animation_Comédie musicale_Famille', 'Comédie_Famille_Policier',
#        'Comédie musicale_Fantastique_Romance',
#        'Biopic_Drame_Policier_Thriller', 'Action_Historique_Thriller',
#        'Aventure_Epouvante_horreur_Fantastique',
#        'Historique_Policier_Thriller',
#        'Animation_Comédie_Drame_Famille_Fantastique', 'Biopic_Comédie',
#        'Action_Animation', 'Comédie_Drame_Policier',
#        'Comédie dramatique_Drame_Fantastique', 'Espionnage_Policier',
#        'Biopic_Epouvante_horreur', 'Action_Animation_Policier',
#        'Comédie_Drame_Policier_Thriller', 'Animation_Drame_Romance',
#        'Famille_Fantastique', 'Animation_Comédie_Drame_Famille',
#        'Drame_Espionnage', 'Action_Animation_Famille',
#        'Comédie_Fantastique_Science fiction', 'Action_Comédie dramatique',
#        'Action_Romance_Thriller', 'Action_Guerre_Thriller',
#        'Drame_Espionnage_Musical_Romance', 'Biopic_Comédie musicale',
#        'Drame_Policier_Science fiction', 'Bollywood_Drame_Historique',
#        'Action_Bollywood_Thriller', 'Bollywood_Comédie_Drame',
#        'Action_Bollywood_Historique', 'Famille_Romance_Science fiction',
#        'Aventure_Epouvante_horreur',
#        'Comédie dramatique_Comédie_Drame_Policier',
#        'Biopic_Guerre_Historique', 'Action_Arts Martiaux_Biopic_Drame',
#        'Comédie dramatique_Comédie_Drame_Epouvante_horreur',
#        'Action_Epouvante_horreur', 'Action_Animation_Policier_Thriller',
#        'Aventure_Comédie_Musical_Science fiction',
#        'Biopic_Drame_Historique_Thriller',
#        'Action_Comédie musicale_Comédie_Drame_Romance',
#        'Comédie_Epouvante_horreur_Science fiction',
#        'Action_Arts Martiaux_Aventure_Thriller',
#        'Drame_Fantastique_Historique', 'Action_Animation_Fantastique',
#        'Animation_Fantastique_Romance',
#        'Action_Animation_Drame_Fantastique', 'Famille',
#        'Action_Animation_Comédie_Drame_Policier',
#        'Drame_Epouvante_horreur_Science fiction_Thriller',
#        'Comédie_Drame_Romance_Science fiction',
#        'Action_Animation_Comédie_Famille',
#        'Action_Arts Martiaux_Comédie_Drame_Science fiction',
#        'Action_Aventure_Comédie_Science fiction',
#        'Comédie musicale_Comédie_Science fiction',
#        'Action_Animation_Arts Martiaux_Fantastique',
#        'Animation_Arts Martiaux_Comédie_Famille',
#        'Bollywood_Drame_Romance', 'Animation_Thriller',
#        'Animation_Drame_Fantastique_Historique_Musical',
#        'Comédie_Epouvante_horreur_Thriller', 'Comédie_Historique_Romance',
#        'Comédie dramatique_Comédie_Drame_Judiciaire_Policier',
#        'Animation_Drame_Science fiction',
#        'Action_Aventure_Comédie_Fantastique',
#        'Animation_Epouvante_horreur_Expérimental_Fantastique',
#        'Action_Aventure_Drame_Historique', 'Musical_Science fiction',
#        'Biopic_Epouvante_horreur_Fantastique',
#        'Action_Animation_Aventure_Fantastique',
#        'Aventure_Famille_Fantastique_Science fiction'], dtype=object)

# %%
# # Split the values in the 'nationalités' column by commas and create a list of nationalities
# data_propre['nationalités'] = data_propre['nationalités'].apply(lambda x: x.split(',') if pd.notnull(x) else [])

# # Flatten the list of nationalities and remove leading/trailing whitespaces
# data_propre['nationalités'] = data_propre['nationalités'].apply(lambda x: [nationality.strip() for nationality in x])

# %%
# data_propre.head(50)

# %%
data_propre['date'].unique()
# Out:
# <DatetimeArray>
# ['1934-04-06 00:00:00', '1947-12-10 00:00:00', '1950-12-01 00:00:00',
#  '1964-10-28 00:00:00', '1968-04-26 00:00:00', '1971-12-08 00:00:00',
#  '1974-09-11 00:00:00', '1979-09-26 00:00:00', '1981-09-16 00:00:00',
#  '1982-12-01 00:00:00',
#  ...
#  '2023-05-12 00:00:00', '2023-05-16 00:00:00', '2023-05-17 00:00:00',
#  '2023-05-24 00:00:00', '2023-05-31 00:00:00', '2023-06-07 00:00:00',
#  '2023-06-14 00:00:00', '2023-06-21 00:00:00', '2023-06-23 00:00:00',
#  '2023-06-28 00:00:00']
# Length: 1592, dtype: datetime64[ns]

# %%
data_propre['langue_d_origine'].unique()
# Out:
# array(['Anglais', 'Polonais', 'Français', 'Cantonais', 'Italien',
#        'Espagnol', '-', 'Allemand', 'Suédois', 'Chinois', 'Bosniaque',
#        'Farsi', 'Japonais', 'Russe', 'Arabe', 'Finnois', 'Coréen',
#        'Mandarin', 'Araméen', 'Serbe', 'Autre', 'Hebreu', 'Créole',
#        'Thaï', 'Mongol', 'Hindi', 'Algérien', 'Afrikaans', 'Néerlandais',
#        'Turc', 'Roumain', 'Serbo-Croate', 'Portugais', 'Islandais',
#        'Dialecte africain', 'Danois', 'Hongrois', 'macédonien', 'Tchèque',
#        'Perse', 'Grec', 'Filipino', 'Kurde', 'Amharique', 'Bulgare',
#        'Kazakh', 'Slovène', 'Vietnamien', 'Albanian', 'Norvégien',
#        'Catalan', 'Flamand', 'Indonésien', 'Estonien', 'Bengali',
#        'Lingala', 'Arménien', 'Tamoul', 'Géorgien', 'Urdu',
#        'Langue des signes', 'Lituanien', 'Suisse allemand', 'Swahili',
#        'Muet', 'Langue aborigène', 'Khmer', 'birman', 'Bambara',
#        'Slovaque', 'Tibétain', 'Kirghize', 'ukrainien', 'Letton',
#        'Galicien', 'Wolof', 'Malgache', 'Yiddish', 'Gaélique'],
#       dtype=object)

# %%
# data_genres_explode=data_propre.explode("genre")         
# data_genres_explode.unique()
# data_genres_explode

# %%
# data_genres_explode.value_counts()

# %%
# Séparation des genres pour obtenir une liste de genres
genres_list = data_propre['genre'].str.split(',')
# Création d'un nouveau DataFrame avec les valeurs uniques des genres
unique_genres_df = pd.DataFrame({'genre_unique': pd.Series(list(set([genre for sublist in genres_list for genre in sublist])))})

# Sauvegarde du DataFrame dans un nouveau fichier CSV
# unique_genres_df.to_csv('genres_uniques.csv', index=False)
unique_genres_df
# Out:
#                                        genre_unique
# 0                                     Action_Guerre
# 1    Animation_Aventure_Fantastique_Science fiction
# 2                               Judiciaire_Thriller
# 3        Animation_Comédie musicale_Famille_Romance
# 4                        Comédie dramatique_Famille
# ..                                              ...
# 472                 Comédie_Drame_Policier_Thriller
# 473                       Animation_Comédie_Musical
# 474                        Aventure_Science fiction
# 475                        Action_Policier_Thriller
# 476                     Aventure_Fantastique_Péplum
#
# [477 rows x 1 columns]

# %%
data_propre.shape
# Out:
# (7015, 16)

# %% [markdown]
# ## Export CSVs

# %%
nationnalité_individual = data_propre['nationalites'].explode()

# Éliminer les doublons pour obtenir les genres uniques
nationnalité_uniques = nationnalité_individual.drop_duplicates()
nationnalité_uniques.shape
# Sauvegarder les genres uniques dans un fichier CSV
# nationnalité_uniques.to_csv('nationnalité_uniques.csv', index=False)

# %%
genre_csv = data_propre['genre'].explode()

# Éliminer les doublons pour obtenir les genres uniques
genre_csv = genre_csv.drop_duplicates()
# genre_csv.to_csv('genre_unique.csv', index=False)

# %%
data_explode= data_propre['genre'].explode()
genre_counts = data_explode.value_counts()
print(genre_counts)
print(genre_counts.nunique())
# Out:
# genre
# Drame                                           1593
# Comédie                                          835
# Comédie dramatique                               413
# Drame_Romance                                    224
# Drame_Thriller                                   217
#                                                 ...
# Action_Aventure_Fantastique_Historique             1
# Comédie musicale_Drame_Historique                  1
# Action_Aventure_Historique                         1
# Animation_Aventure_Comédie_Fantastique             1
# Aventure_Famille_Fantastique_Science fiction       1
# Name: count, Length: 477, dtype: int64
# 54

# %%
langue_d_origine_gh = data_propre['langue_d_origine'].explode()

# Éliminer les doublons pour obtenir les genres uniques
langue_d_origine_gh = langue_d_origine_gh.drop_duplicates()
langue_d_origine_gh.shape
# langue_d_origine_gh.to_csv('langue_d_origine_gh.csv', index=False)

# %%
date_csv=data_propre['date'].explode()
date_csv = date_csv.drop_duplicates()
# date_csv.to_csv('date.csv', index=False)

# %% [markdown]
# ## <font color="green"> VI- Export silver Data </font>

# %%
#EXporter la data dans un Csv 
data_propre.to_csv('../Feature_engineering/data/dataset_model_silver.csv', index=False)
